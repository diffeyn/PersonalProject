# %%
import pandas as pd
import glob
import re

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data_files/scraped_raw/matches/feed/mls_match_feeds_no_dupes.csv')

# %%
df
# Out:
#        match_id                   date minute               title  \
# 0      f6700cd1  Wednesday May 15 2024    NaN  END OF SECOND HALF
# 1      f6700cd1  Wednesday May 15 2024    NaN           FULL TIME
# 2      f6700cd1  Wednesday May 15 2024  90'+6       Attempt Saved
# 3      f6700cd1  Wednesday May 15 2024  90'+5       Attempt Saved
# 4      f6700cd1  Wednesday May 15 2024    89'      Attempt Missed
# ...         ...                    ...    ...                 ...
# 43705  914361ab   Sunday March 10 2024    15'       Attempt Saved
# 43706  914361ab   Sunday March 10 2024    11'       Attempt Saved
# 43707  914361ab   Sunday March 10 2024     6'       Attempt Saved
# 43708  914361ab   Sunday March 10 2024     3'       Attempt Saved
# 43709  914361ab   Sunday March 10 2024    NaN            KICK OFF
#
#                                                  comment out_player in_player
# 0                                          End of match.        NaN       NaN
# 1      Second half ends, Chicago Fire FC 0, Charlotte...        NaN       NaN
# 2      Attempt saved. Carlos Terán's (Chicago Fire FC...        NaN       NaN
# 3      Attempt saved. Hugo Cuypers's (Chicago Fire FC...        NaN       NaN
# 4      Attempt missed. Kerwin Vargas's (Charlotte FC)...        NaN       NaN
# ...                                                  ...        ...       ...
# 43705  Attempt blocked. Matti Peltola's (D.C. United)...        NaN       NaN
# 43706  Attempt saved. Jackson Hopkins's (D.C. United)...        NaN       NaN
# 43707  Attempt saved. Matt Miazga's (FC Cincinnati) w...        NaN       NaN
# 43708  Attempt saved. Mateusz Klich's (D.C. United) w...        NaN       NaN
# 43709                                 First half begins.        NaN       NaN
#
# [43710 rows x 7 columns]

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
month_map = {
        "january": "01", "february": "02", "march": "03", "april": "04",
        "may": "05", "june": "06", "july": "07", "august": "08",
        "september": "09", "october": "10", "november": "11", "december": "12",
        "jan": "01", "feb": "02", "mar": "03", "apr": "04",
        "jun": "06", "jul": "07", "aug": "08",
        "sep": "09", "oct": "10", "nov": "11", "dec": "12"
    }

# %%
### find float in date strings

float_dates = df[df["date"].apply(lambda x: isinstance(x, float))]
float_dates
# Out:
#        match_id date  minute               title  \
# 6741   f0b7242e  NaN     NaN  END OF SECOND HALF
# 6742   f0b7242e  NaN     NaN           FULL TIME
# 6743   f0b7242e  NaN  90'+10                GOAL
# 6744   f0b7242e  NaN   90'+9       Attempt Saved
# 6745   f0b7242e  NaN   90'+6                 NaN
# ...         ...  ...     ...                 ...
# 30452  3c29cb63  NaN      4'      Attempt Missed
# 30453  3c29cb63  NaN      3'       Attempt Saved
# 30454  3c29cb63  NaN      2'      Attempt Missed
# 30455  3c29cb63  NaN      1'       Attempt Saved
# 30456  3c29cb63  NaN     NaN            KICK OFF
#
#                                                  comment       out_player  \
# 6741                                       End of match.              NaN
# 6742   Second half ends, Columbus Crew 4, New York Ci...              NaN
# 6743   Goal! 4:2. Jacen Russell-Rowe (Columbus Crew) ...              NaN
# 6744   Attempt saved. Diego Rossi's (Columbus Crew) w...              NaN
# 6745                                                 NaN  Cucho Hernández
# ...                                                  ...              ...
# 30452  Attempt missed. Diogo Gonçalves's (Real Salt L...              NaN
# 30453  Attempt blocked. Amahl Pellegrino's (San Jose ...              NaN
# 30454  Attempt missed. Cristian Arango's (Real Salt L...              NaN
# 30455  Attempt blocked. Jackson Yueill's (San Jose Ea...              NaN
# 30456                                 First half begins.              NaN
#
#          in_player
# 6741           NaN
# 6742           NaN
# 6743           NaN
# 6744           NaN
# 6745   D. Chambost
# ...            ...
# 30452          NaN
# 30453          NaN
# 30454          NaN
# 30455          NaN
# 30456          NaN
#
# [135 rows x 7 columns]

# %%
## fill match id f0b7242e with date "Saturday Aug 31, 2024"

df.loc[df['match_id'] == 'f0b7242e', 'date'] = 'Saturday Aug 31, 2024'

### fill match id 3c29cb63 with Saturday Aug 24, 2024

df.loc[df['match_id'] == '3c29cb63', 'date'] = 'Saturday Aug 24, 2024'

### fill match id bec23bed with Saturday Sep 20

df.loc[df['match_id'] == 'bec23bed', 'date'] = 'Saturday Sep 20'

# %%
## drop row # 16194 

df = df.drop(index=16194)

# %%
### find float in date strings

float_dates2 = df[df["date"].apply(lambda x: isinstance(x, float))]
float_dates2
# Out:
# Empty DataFrame
# Columns: [match_id, date, minute, title, comment, out_player, in_player]
# Index: []

# %%
## remove day names from date strings

df['date'] = df['date'].apply(lambda x: ' '.join([word for word in x.split() if word not in days]))

# %%
df['date'] = df['date'].apply(
        lambda x: re.sub(
            r"([A-Za-z]+)",
            lambda m: month_map[m.group(1).lower()],
            x
        )
    )

df['date'] = df['date'].apply(lambda x: x + " 2025" if re.search(r"\d{4}$", x) is None else x)

### remove , from date strings

df['date'] = df['date'].apply(lambda x: x.replace(',', ''))

# %%
#### convert date column to datetime from mm dd yyyy format

df['date'] = pd.to_datetime(df['date'], format="%m %d %Y")

# %%
## if corner in comment, then title is corner

df['title'] = df.apply(lambda x: 'Corner' if pd.notna(x['comment']) and 'corner' in x['comment'].lower() else x['title'], axis=1)

df['title'] = df.apply(lambda x: 'Foul' if pd.notna(x['comment']) and 'foul' in x['comment'].lower() else x['title'], axis=1)

df['title'] = df.apply(lambda x: 'Offside' if pd.notna(x['comment']) and 'offside' in x['comment'].lower() else x['title'], axis=1)

# %%
clubs = [
    "Atlanta United",
    "Austin FC",
    "CF Montréal",
    "Charlotte FC",
    "Chicago Fire FC",
    "FC Cincinnati",
    "Colorado Rapids",
    "Columbus Crew",
    "D.C. United",
    "FC Dallas",
    "Houston Dynamo FC",
    "Sporting Kansas City",
    "LA Galaxy",
    "Los Angeles Football Club",
    "Inter Miami CF",
    "Minnesota United FC",
    "Minnesota United",
    "Nashville SC",
    "New England Revolution",
    "New York City Football Club",
    "New York City FC",
    "New York Red Bulls",
    "Orlando City",
    "Philadelphia Union",
    "Portland Timbers",
    "Real Salt Lake",
    "San Diego FC",
    "San Jose Earthquakes",
    "Seattle Sounders FC",
    "St. Louis CITY SC",
    "Toronto FC",
    "Vancouver Whitecaps FC"
]

team_map = {
    "Atlanta United": "ATL",
    "Austin FC": "ATX",
    "CF Montréal": "MTL",
    "Charlotte FC": "CLT",
    "Chicago Fire FC": "CHI",
    "FC Cincinnati": "CIN",
    "Colorado Rapids": "COL",
    "Columbus Crew": "CLB",
    "D.C. United": "DC",
    "FC Dallas": "DAL",
    "Houston Dynamo FC": "HOU",
    "Sporting Kansas City": "SKC",
    "LA Galaxy": "LA",
    "Los Angeles Football Club": "LAFC",
    "Inter Miami CF": "MIA",
    "Minnesota United": "MIN",
    "Minnesota United FC": "MIN",
    "Nashville SC": "NSH",
    "New England Revolution": "NE",
    "New York City Football Club": "NYC",
    "New York City FC": "NYC",
    "New York Red Bulls": "RBNY",
    "Orlando City": "ORL",
    "Philadelphia Union": "PHI",
    "Portland Timbers": "POR",
    "Real Salt Lake": "RSL",
    "San Diego FC": "SD",
    "San Jose Earthquakes": "SJ",
    "Seattle Sounders FC": "SEA",
    "St. Louis CITY SC": "STL",
    "Toronto FC": "TOR",
    "Vancouver Whitecaps FC": "VAN"
}




def assign_teams_from_fulltime(df):
    df = df.copy()

    # create output columns
    df["home_team"] = None
    df["away_team"] = None

    # Improved regex: allow apostrophes, accents, FC, SC, etc.
    pattern = re.compile(
        r"Second half ends,\s*([A-Za-zÀ-ÿ .'-]+?)\s+\d+,\s*([A-Za-zÀ-ÿ .'-]+?)\s+\d+",
        re.IGNORECASE
    )

    for mid, group in df.groupby("match_id"):

        ft = group[group["title"].str.contains("FULL TIME", case=False, na=False)]

        if len(ft) == 0:
            continue

        comment = ft.iloc[0]["comment"]

        match = pattern.search(comment)
        if not match:
            continue

        home_full = match.group(1).strip()
        away_full = match.group(2).strip()

        # 1. Exact match
        home_short = team_map.get(home_full)
        away_short = team_map.get(away_full)

        # 2. If exact match failed, try fuzzy match from clubs list
        if home_short is None:
            for club in clubs:
                if club.lower() in home_full.lower():
                    home_short = team_map.get(club)
                    break

        if away_short is None:
            for club in clubs:
                if club.lower() in away_full.lower():
                    away_short = team_map.get(club)
                    break

        # 3. Final fallback → None
        # (Later you can log missing clubs if needed)

        df.loc[df.match_id == mid, "home_team"] = home_short
        df.loc[df.match_id == mid, "away_team"] = away_short

    return df

# %%
df = assign_teams_from_fulltime(df)

# %%
df
# Out:
#        match_id       date minute               title  \
# 0      f6700cd1 2024-05-15    NaN  END OF SECOND HALF
# 1      f6700cd1 2024-05-15    NaN           FULL TIME
# 2      f6700cd1 2024-05-15  90'+6       Attempt Saved
# 3      f6700cd1 2024-05-15  90'+5       Attempt Saved
# 4      f6700cd1 2024-05-15    89'      Attempt Missed
# ...         ...        ...    ...                 ...
# 43705  914361ab 2024-03-10    15'       Attempt Saved
# 43706  914361ab 2024-03-10    11'       Attempt Saved
# 43707  914361ab 2024-03-10     6'       Attempt Saved
# 43708  914361ab 2024-03-10     3'       Attempt Saved
# 43709  914361ab 2024-03-10    NaN            KICK OFF
#
#                                                  comment out_player in_player  \
# 0                                          End of match.        NaN       NaN
# 1      Second half ends, Chicago Fire FC 0, Charlotte...        NaN       NaN
# 2      Attempt saved. Carlos Terán's (Chicago Fire FC...        NaN       NaN
# 3      Attempt saved. Hugo Cuypers's (Chicago Fire FC...        NaN       NaN
# 4      Attempt missed. Kerwin Vargas's (Charlotte FC)...        NaN       NaN
# ...                                                  ...        ...       ...
# 43705  Attempt blocked. Matti Peltola's (D.C. United)...        NaN       NaN
# 43706  Attempt saved. Jackson Hopkins's (D.C. United)...        NaN       NaN
# 43707  Attempt saved. Matt Miazga's (FC Cincinnati) w...        NaN       NaN
# 43708  Attempt saved. Mateusz Klich's (D.C. United) w...        NaN       NaN
# 43709                                 First half begins.        NaN       NaN
#
#       home_team away_team
# 0           CHI       CLT
# 1           CHI       CLT
# 2           CHI       CLT
# 3           CHI       CLT
# 4           CHI       CLT
# ...         ...       ...
# 43705       CIN        DC
# 43706       CIN        DC
# 43707       CIN        DC
# 43708       CIN        DC
# 43709       CIN        DC
#
# [43709 rows x 9 columns]

# %%
### check for na teams

df[df['home_team'].isna() | df['away_team'].isna()]
# Out:
#        match_id       date minute           title  \
# 16068  4f9ec18f 2024-04-06    22'   Attempt Saved
# 16069  4f9ec18f 2024-04-06    16'   Attempt Saved
# 16070  4f9ec18f 2024-04-06    NaN        KICK OFF
# 28213  9f82627f 2024-06-15    86'             NaN
# 28214  9f82627f 2024-06-15    82'  Attempt Missed
# ...         ...        ...    ...             ...
# 40201  0a6cd237 2024-06-08    16'  Attempt Missed
# 40202  0a6cd237 2024-06-08    14'  Attempt Missed
# 40203  0a6cd237 2024-06-08    10'  Attempt Missed
# 40204  0a6cd237 2024-06-08     3'   Attempt Saved
# 40205  0a6cd237 2024-06-08    NaN        KICK OFF
#
#                                                  comment  out_player  \
# 16068  Attempt saved. Amine Bassi's (Houston Dynamo F...         NaN
# 16069  Attempt saved. Fabian Herbers's (Chicago Fire ...         NaN
# 16070                                 First half begins.         NaN
# 28213                                                NaN  R. Navarro
# 28214  Attempt missed. Sebastián Driussi's (Austin FC...         NaN
# ...                                                  ...         ...
# 40201  Attempt missed. Tim Parker's (St. Louis CITY S...         NaN
# 40202  Attempt missed. Nathan Fogaça's (Portland Timb...         NaN
# 40203  João Klauss (St. Louis CITY SC) with header fr...         NaN
# 40204  Attempt saved. Jonathan Rodríguez's (Portland ...         NaN
# 40205                                 First half begins.         NaN
#
#       in_player home_team away_team
# 16068       NaN      None      None
# 16069       NaN      None      None
# 16070       NaN      None      None
# 28213   D. Yapi      None      None
# 28214       NaN      None      None
# ...         ...       ...       ...
# 40201       NaN      None      None
# 40202       NaN      None      None
# 40203       NaN      None      None
# 40204       NaN      None      None
# 40205       NaN      None      None
#
# [71 rows x 9 columns]

# %%
### delete na team rows

df = df[~(df['home_team'].isna() | df['away_team'].isna())]

# %%
### delete row is 'lineups' is in comment

df = df[~df['comment'].str.contains('Lineups', na=False)]

df = df[~df['title'].str.contains('KICK OFF|HALF TIME|FULL TIME|END OF SECOND HALF', na=False)]

# %%
df
# Out:
#        match_id       date minute           title  \
# 2      f6700cd1 2024-05-15  90'+6   Attempt Saved
# 3      f6700cd1 2024-05-15  90'+5   Attempt Saved
# 4      f6700cd1 2024-05-15    89'  Attempt Missed
# 5      f6700cd1 2024-05-15    87'             NaN
# 6      f6700cd1 2024-05-15    84'   Attempt Saved
# ...         ...        ...    ...             ...
# 43704  914361ab 2024-03-10    19'   Attempt Saved
# 43705  914361ab 2024-03-10    15'   Attempt Saved
# 43706  914361ab 2024-03-10    11'   Attempt Saved
# 43707  914361ab 2024-03-10     6'   Attempt Saved
# 43708  914361ab 2024-03-10     3'   Attempt Saved
#
#                                                  comment  out_player  \
# 2      Attempt saved. Carlos Terán's (Chicago Fire FC...         NaN
# 3      Attempt saved. Hugo Cuypers's (Chicago Fire FC...         NaN
# 4      Attempt missed. Kerwin Vargas's (Charlotte FC)...         NaN
# 5                                                    NaN  João Pedro
# 6      Attempt blocked. Kerwin Vargas's (Charlotte FC...         NaN
# ...                                                  ...         ...
# 43704  Attempt blocked. Cristian Dájome's (D.C. Unite...         NaN
# 43705  Attempt blocked. Matti Peltola's (D.C. United)...         NaN
# 43706  Attempt saved. Jackson Hopkins's (D.C. United)...         NaN
# 43707  Attempt saved. Matt Miazga's (FC Cincinnati) w...         NaN
# 43708  Attempt saved. Mateusz Klich's (D.C. United) w...         NaN
#
#         in_player home_team away_team
# 2             NaN       CHI       CLT
# 3             NaN       CHI       CLT
# 4             NaN       CHI       CLT
# 5      J. Lindsey       CHI       CLT
# 6             NaN       CHI       CLT
# ...           ...       ...       ...
# 43704         NaN       CIN        DC
# 43705         NaN       CIN        DC
# 43706         NaN       CIN        DC
# 43707         NaN       CIN        DC
# 43708         NaN       CIN        DC
#
# [38657 rows x 9 columns]

# %%
## if minute is missing, delete

df = df[df['minute'].notna()]

# %%
### reverse minute sorting

df = df.iloc[::-1].reset_index(drop=True)

# %%
### if title is missing, fill with 'Substitution' 
df['title'] = df['title'].fillna('Substitution')

### move in_player and out_player to comment if title is Substitution
df['comment'] = df.apply(lambda x: f"Substitution: {x['out_player']} out, {x['in_player']} in" if x['title'] == 'Substitution' else x['comment'], axis=1)

# %%
### add feed_id per match 
df['feed_id'] = df.groupby('match_id').cumcount() + 1

# %%
df
# Out:
#        match_id       date minute           title  \
# 0      914361ab 2024-03-10     3'   Attempt Saved
# 1      914361ab 2024-03-10     6'   Attempt Saved
# 2      914361ab 2024-03-10    11'   Attempt Saved
# 3      914361ab 2024-03-10    15'   Attempt Saved
# 4      914361ab 2024-03-10    19'   Attempt Saved
# ...         ...        ...    ...             ...
# 38652  f6700cd1 2024-05-15    84'   Attempt Saved
# 38653  f6700cd1 2024-05-15    87'    Substitution
# 38654  f6700cd1 2024-05-15    89'  Attempt Missed
# 38655  f6700cd1 2024-05-15  90'+5   Attempt Saved
# 38656  f6700cd1 2024-05-15  90'+6   Attempt Saved
#
#                                                  comment  out_player  \
# 0      Attempt saved. Mateusz Klich's (D.C. United) w...         NaN
# 1      Attempt saved. Matt Miazga's (FC Cincinnati) w...         NaN
# 2      Attempt saved. Jackson Hopkins's (D.C. United)...         NaN
# 3      Attempt blocked. Matti Peltola's (D.C. United)...         NaN
# 4      Attempt blocked. Cristian Dájome's (D.C. Unite...         NaN
# ...                                                  ...         ...
# 38652  Attempt blocked. Kerwin Vargas's (Charlotte FC...         NaN
# 38653        Substitution: João Pedro out, J. Lindsey in  João Pedro
# 38654  Attempt missed. Kerwin Vargas's (Charlotte FC)...         NaN
# 38655  Attempt saved. Hugo Cuypers's (Chicago Fire FC...         NaN
# 38656  Attempt saved. Carlos Terán's (Chicago Fire FC...         NaN
#
#         in_player home_team away_team  feed_id
# 0             NaN       CIN        DC        1
# 1             NaN       CIN        DC        2
# 2             NaN       CIN        DC        3
# 3             NaN       CIN        DC        4
# 4             NaN       CIN        DC        5
# ...           ...       ...       ...      ...
# 38652         NaN       CHI       CLT       30
# 38653  J. Lindsey       CHI       CLT       31
# 38654         NaN       CHI       CLT       32
# 38655         NaN       CHI       CLT       33
# 38656         NaN       CHI       CLT       34
#
# [38657 rows x 10 columns]

# %%
## sort by date desc

df = df.sort_values(by=['date', 'match_id', 'feed_id'], ascending=[False, True, False]).reset_index(drop=False)

# %%
df
# Out:
#        index  match_id       date minute           title  \
# 0       3242  04a4ef01 2025-10-18  90'+7  Attempt Missed
# 1       3241  04a4ef01 2025-10-18  90'+7            Foul
# 2       3240  04a4ef01 2025-10-18  90'+5          Corner
# 3       3239  04a4ef01 2025-10-18    89'    Substitution
# 4       3238  04a4ef01 2025-10-18    83'   Attempt Saved
# ...      ...       ...        ...    ...             ...
# 38652  12781  1cfa7fdb 2024-02-21    23'   Attempt Saved
# 38653  12780  1cfa7fdb 2024-02-21    21'   Attempt Saved
# 38654  12779  1cfa7fdb 2024-02-21    20'   Attempt Saved
# 38655  12778  1cfa7fdb 2024-02-21    15'            Foul
# 38656  12777  1cfa7fdb 2024-02-21     6'  Attempt Missed
#
#                                                  comment   out_player  \
# 0      Attempt missed. Nicolás Romero's (Minnesota Un...          NaN
# 1      Edwin Cerrillo (LA Galaxy) is shown the second...          NaN
# 2      Goal! 2:1. Joaquín Pereyra (Minnesota United F...          NaN
# 3            Substitution: J. Paintsil out, T. Lepley in  J. Paintsil
# 4      Attempt blocked. Joaquín Pereyra's (Minnesota ...          NaN
# ...                                                  ...          ...
# 38652  Attempt saved. Diego Gómez's (Inter Miami CF) ...          NaN
# 38653  Attempt blocked. Lionel Messi's (Inter Miami C...          NaN
# 38654  Attempt saved. Luis Suárez's (Inter Miami CF) ...          NaN
# 38655  Pablo Ruiz (Real Salt Lake) is shown the yello...          NaN
# 38656  Attempt missed. Luis Suárez's (Inter Miami CF)...          NaN
#
#        in_player home_team away_team  feed_id
# 0            NaN        LA       MIN       36
# 1            NaN        LA       MIN       35
# 2            NaN        LA       MIN       34
# 3      T. Lepley        LA       MIN       33
# 4            NaN        LA       MIN       32
# ...          ...       ...       ...      ...
# 38652        NaN       MIA       RSL        5
# 38653        NaN       MIA       RSL        4
# 38654        NaN       MIA       RSL        3
# 38655        NaN       MIA       RSL        2
# 38656        NaN       MIA       RSL        1
#
# [38657 rows x 11 columns]

# %%
### remove in_player and out_player columns
df = df.drop(columns=['in_player', 'out_player'])

# %%
### reorder columns
df = df[['match_id', 'date', 'feed_id', 'minute', 'title', 'comment', 'home_team', 'away_team']]

# %%
df
# Out:
#        match_id       date  feed_id minute           title  \
# 0      04a4ef01 2025-10-18       36  90'+7  Attempt Missed
# 1      04a4ef01 2025-10-18       35  90'+7            Foul
# 2      04a4ef01 2025-10-18       34  90'+5          Corner
# 3      04a4ef01 2025-10-18       33    89'    Substitution
# 4      04a4ef01 2025-10-18       32    83'   Attempt Saved
# ...         ...        ...      ...    ...             ...
# 38652  1cfa7fdb 2024-02-21        5    23'   Attempt Saved
# 38653  1cfa7fdb 2024-02-21        4    21'   Attempt Saved
# 38654  1cfa7fdb 2024-02-21        3    20'   Attempt Saved
# 38655  1cfa7fdb 2024-02-21        2    15'            Foul
# 38656  1cfa7fdb 2024-02-21        1     6'  Attempt Missed
#
#                                                  comment home_team away_team
# 0      Attempt missed. Nicolás Romero's (Minnesota Un...        LA       MIN
# 1      Edwin Cerrillo (LA Galaxy) is shown the second...        LA       MIN
# 2      Goal! 2:1. Joaquín Pereyra (Minnesota United F...        LA       MIN
# 3            Substitution: J. Paintsil out, T. Lepley in        LA       MIN
# 4      Attempt blocked. Joaquín Pereyra's (Minnesota ...        LA       MIN
# ...                                                  ...       ...       ...
# 38652  Attempt saved. Diego Gómez's (Inter Miami CF) ...       MIA       RSL
# 38653  Attempt blocked. Lionel Messi's (Inter Miami C...       MIA       RSL
# 38654  Attempt saved. Luis Suárez's (Inter Miami CF) ...       MIA       RSL
# 38655  Pablo Ruiz (Real Salt Lake) is shown the yello...       MIA       RSL
# 38656  Attempt missed. Luis Suárez's (Inter Miami CF)...       MIA       RSL
#
# [38657 rows x 8 columns]

# %%
### check for nan teams

df[df['home_team'].isna() | df['away_team'].isna()]
# Out:
# Empty DataFrame
# Columns: [match_id, date, feed_id, minute, title, comment, home_team, away_team]
# Index: []

# %%
df
# Out:
#        match_id       date  feed_id minute           title  \
# 0      04a4ef01 2025-10-18       36  90'+7  Attempt Missed
# 1      04a4ef01 2025-10-18       35  90'+7            Foul
# 2      04a4ef01 2025-10-18       34  90'+5          Corner
# 3      04a4ef01 2025-10-18       33    89'    Substitution
# 4      04a4ef01 2025-10-18       32    83'   Attempt Saved
# ...         ...        ...      ...    ...             ...
# 38652  1cfa7fdb 2024-02-21        5    23'   Attempt Saved
# 38653  1cfa7fdb 2024-02-21        4    21'   Attempt Saved
# 38654  1cfa7fdb 2024-02-21        3    20'   Attempt Saved
# 38655  1cfa7fdb 2024-02-21        2    15'            Foul
# 38656  1cfa7fdb 2024-02-21        1     6'  Attempt Missed
#
#                                                  comment home_team away_team
# 0      Attempt missed. Nicolás Romero's (Minnesota Un...        LA       MIN
# 1      Edwin Cerrillo (LA Galaxy) is shown the second...        LA       MIN
# 2      Goal! 2:1. Joaquín Pereyra (Minnesota United F...        LA       MIN
# 3            Substitution: J. Paintsil out, T. Lepley in        LA       MIN
# 4      Attempt blocked. Joaquín Pereyra's (Minnesota ...        LA       MIN
# ...                                                  ...       ...       ...
# 38652  Attempt saved. Diego Gómez's (Inter Miami CF) ...       MIA       RSL
# 38653  Attempt blocked. Lionel Messi's (Inter Miami C...       MIA       RSL
# 38654  Attempt saved. Luis Suárez's (Inter Miami CF) ...       MIA       RSL
# 38655  Pablo Ruiz (Real Salt Lake) is shown the yello...       MIA       RSL
# 38656  Attempt missed. Luis Suárez's (Inter Miami CF)...       MIA       RSL
#
# [38657 rows x 8 columns]

# %%
df.to_csv(
    "../../data_files/cleaned/matches/feed/cleaned_mls_match_feeds2.csv",
    index=False)

# %%
def clean_feed(df):
    df = df.copy()
    
    df['title'] = df.apply(lambda x: 'Corner' if pd.notna(x['comment']) and 'corner' in x['comment'].lower() else x['title'], axis=1)

    df['title'] = df.apply(lambda x: 'Foul' if pd.notna(x['comment']) and 'foul' in x['comment'].lower() else x['title'], axis=1)

    df['title'] = df.apply(lambda x: 'Offside' if pd.notna(x['comment']) and 'offside' in x['comment'].lower() else x['title'], axis=1)   
    
    df = df[~df['comment'].str.contains('Lineups', na=False)]

    df = df[~df['title'].str.contains('KICK OFF|HALF TIME|FULL TIME|END OF SECOND HALF', na=False)]
    
    df = df[df['minute'].notna()]
    
    df = df.iloc[::-1].reset_index(drop=True)
    
    df['title'] = df['title'].fillna('Substitution')

    df['comment'] = df.apply(lambda x: f"Substitution: {x['out_player']} out, {x['in_player']} in" if x['title'] == 'Substitution' else x['comment'], axis=1)
    
    df['feed_id'] = df.groupby('match_id').cumcount() + 1
    
    df['date'] = df['date'].astype(str)
    
    df['date'] = df['date'].str.replace(r"^[A-Za-z]+ ", "", regex=True)

    month_map = {
        "january": "01", "february": "02", "march": "03", "april": "04",
        "may": "05", "june": "06", "july": "07", "august": "08",
        "september": "09", "october": "10", "november": "11", "december": "12"
    }

    df['date'] = df['date'].apply(
        lambda x: re.sub(
            r"[A-Za-z]+",
            lambda m: month_map.get(m.group(0).lower(), m.group(0)),
            x
        )
    )

    df['date'] = df['date'].apply(
        lambda x: x + " 2025" if not re.search(r"\b\d{4}\b", x) else x
    )
    
    df['date'] = pd.to_datetime(df['date'], format="%m %d %Y")
    
    df = df.drop(columns=['in_player', 'out_player'])

    df = df[['match_id', 'date', 'feed_id', 'minute', 'title', 'comment']]
    
    return df

# %%
for file in glob.glob('G:/My Drive/GitHubProjects/MLS/data_files/scraped_raw/matches/feed/mls_match_feeds.csv'):
    df = pd.read_csv(file)
    cleaned_df = clean_feed(df)
    cleaned_df.to_csv(
        f"G:/My Drive/GitHubProjects/MLS/data_files/cleaned/matches/feed/cleaned_mls_match_feeds.csv",
        index=False)
