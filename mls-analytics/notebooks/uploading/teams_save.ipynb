# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('../../data_files/cleaned/teams/master_teams.csv')

# %%
df
# Out:
#        team_id               team_name  overall_score  attack  midfield  \
# 0       112893             Inter Miami             72      78        74
# 1       112996          Los Angeles FC             71      75        70
# 2       101112  Vancouver Whitecaps FC             71      73        72
# 3       113149           FC Cincinnati             71      73        71
# 4       111138     Minnesota United FC             70      71        70
# ...        ...                     ...            ...     ...       ...
# 18700      698          Houston Dynamo             64      62        63
# 18701      697               LA Galaxy             63      58        63
# 18702   111070              Chivas USA             63      61        62
# 18703   111065          Real Salt Lake             62      61        62
# 18704      687           Columbus Crew             61      56        59
#
#        defense  worth_euro  num_players     lineup    style        date
# ...

# %%
team_name_to_id = dict(zip(df['team_name'], df['team_id']))

# %%
df = df[['team_id', 'team_name']]

teams_dict = {
    'Inter Miami': 'MIA',
    'Seattle Sounders FC': 'SEA',
    'Los Angeles FC': 'LAFC',
    'LA Galaxy': 'LA',
    'St. Louis CITY SC': 'STL',
    'Charlotte FC': 'CLT',
    'Atlanta United': 'ATL',
    'FC Cincinnati': 'CIN',
    'Portland Timbers': 'POR',
    'San Jose Earthquakes': 'SJ',
    'Columbus Crew': 'CLB',
    'New York Red Bulls': 'RBNY',
    'New England Revolution': 'NE',
    'Houston Dynamo': 'HOU',
    'Orlando City SC': 'ORL',
    'Austin FC': 'ATX',
    'Nashville SC': 'NSH',
    'Vancouver Whitecaps FC': 'VAN',
    'Philadelphia Union': 'PHI',
    'Minnesota United FC': 'MIN',
    'Toronto FC': 'TOR',
    'Chicago Fire': 'CHI',
    'FC Dallas': 'DAL',
    'Sporting Kansas City': 'SKC',
    'Real Salt Lake': 'RSL',
    'DC United': 'DC',
    'Colorado Rapids': 'COL',
    'New York City FC': 'NYC',
    'CF Montréal': 'MTL',
    'San Diego FC': 'SD',
}

# %%
df['team_abbr'] = df['team_name'].map(teams_dict)
# Out:
# C:\Users\diffe\AppData\Local\Temp\ipykernel_40272\2601928823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['team_abbr'] = df['team_name'].map(teams_dict)

# %%
df
# Out:
#        team_id               team_name team_abbr
# 0       112893             Inter Miami       MIA
# 1       112996          Los Angeles FC      LAFC
# 2       101112  Vancouver Whitecaps FC       VAN
# 3       113149           FC Cincinnati       CIN
# 4       111138     Minnesota United FC       MIN
# ...        ...                     ...       ...
# 18700      698          Houston Dynamo       HOU
# 18701      697               LA Galaxy        LA
# 18702   111070              Chivas USA       NaN
# 18703   111065          Real Salt Lake       RSL
# 18704      687           Columbus Crew       CLB
#
# [18705 rows x 3 columns]

# %%
### remove duplicates if any

df = df.drop_duplicates(subset=['team_id'])

# %%
df
# Out:
#        team_id               team_name team_abbr
# 0       112893             Inter Miami       MIA
# 1       112996          Los Angeles FC      LAFC
# 2       101112  Vancouver Whitecaps FC       VAN
# 3       113149           FC Cincinnati       CIN
# 4       111138     Minnesota United FC       MIN
# 5       111140        Portland Timbers       POR
# 6       111144     Seattle Sounders FC       SEA
# 7       131439            San Diego FC        SD
# 8          687           Columbus Crew       CLB
# 9          697               LA Galaxy        LA
# 10      114640            Charlotte FC       CLT
# 11      112885          Atlanta United       ATL
# 12      112134      Philadelphia Union       PHI
# 13         689      New York Red Bulls      RBNY
# 14         691  New England Revolution        NE
# 15         693            Chicago Fire       CHI
# 16         698          Houston Dynamo       HOU
# 17      112828        New York City FC       NYC
# ...

# %%
db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df.to_sql('teams', engine, if_exists='append', index=False)

df.to_csv('../../data_files/cleaned/teams/allteams.csv')
