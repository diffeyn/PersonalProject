# %%
import pandas as pd
from sqlalchemy import create_engine
import os

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df = pd.read_csv('../../data_files/cleaned/players/master_players_w_team_abbr.csv')

# %%
df
# Out:
#             id        date                name   age  height_cm  weight_kg  \
# 0       238919  2023-01-18         J. Pantemis  25.0        188         79
# 1       255956  2023-01-18         J. Waterman  26.0        185         75
# 2       206485  2023-01-18          R. Camacho  31.0        185         79
# 3       247648  2023-01-18           K. Miller  25.0        183         88
# 4       243574  2023-01-18  Z. Brault-Guillard  23.0        171         65
# ...        ...         ...                 ...   ...        ...        ...
# 483224   77495  2025-11-20             M. Duah  19.0        193         82
# 483225   75236  2025-11-20          L. Bombino  18.0        170         73
# 483226   73870  2025-11-20          D. Vazquez  19.0        175         65
# 483227   80612  2025-11-20             P. Soma  19.0        177         75
# 483228   77459  2025-11-20            A. Saidi  17.0        185         67
#
#        team  contract_start  contract_end position  ... total_goalkeeping  \
# 0       MTL          2018.0        2023.0       GK  ...               315
# 1       MTL          2020.0        2023.0      RCB  ...                45
# 2       MTL          2022.0        2023.0       CB  ...                49
# 3       MTL          2021.0        2023.0      LCB  ...                50
# 4       MTL          2020.0        2022.0       RM  ...                50
# ...     ...             ...           ...      ...  ...               ...
# 483224   SD          2024.0        2027.0      RES  ...                52
# 483225   SD             NaN           NaN      NaN  ...                42
# 483226   SD             NaN           NaN      NaN  ...                49
# 483227   SD          2025.0        2027.0      RES  ...                44
# 483228   SD          2025.0        2028.0      RES  ...                57
#
#         gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0              66           63          54              66           66
# 1               6            7          10              11           11
# 2               8            6           6              15           14
# 3               8           11          12               7           12
# 4              11            6          11              11           11
# ...           ...          ...         ...             ...          ...
# 483224         14            7          11               8           12
# 483225         13            8           7               9            5
# 483226         14           10           6              10            9
# 483227         11            6           6              11           10
# 483228          8           14          11               9           15
#
#        marking  tactical_awareness  positioning  tackling
# 0          NaN                 NaN          NaN       NaN
# 1          NaN                 NaN          NaN       NaN
# 2          NaN                 NaN          NaN       NaN
# 3          NaN                 NaN          NaN       NaN
# 4          NaN                 NaN          NaN       NaN
# ...        ...                 ...          ...       ...
# 483224     NaN                 NaN          NaN       NaN
# 483225     NaN                 NaN          NaN       NaN
# 483226     NaN                 NaN          NaN       NaN
# 483227     NaN                 NaN          NaN       NaN
# 483228     NaN                 NaN          NaN       NaN
#
# [483229 rows x 61 columns]

# %%
## rename id to player_id

df.rename(columns={'id': 'player_id'}, inplace=True)

# %%
df
# Out:
#         player_id        date                name   age  height_cm  weight_kg  \
# 0          238919  2023-01-18         J. Pantemis  25.0        188         79
# 1          255956  2023-01-18         J. Waterman  26.0        185         75
# 2          206485  2023-01-18          R. Camacho  31.0        185         79
# 3          247648  2023-01-18           K. Miller  25.0        183         88
# 4          243574  2023-01-18  Z. Brault-Guillard  23.0        171         65
# ...           ...         ...                 ...   ...        ...        ...
# 483224      77495  2025-11-20             M. Duah  19.0        193         82
# 483225      75236  2025-11-20          L. Bombino  18.0        170         73
# 483226      73870  2025-11-20          D. Vazquez  19.0        175         65
# 483227      80612  2025-11-20             P. Soma  19.0        177         75
# 483228      77459  2025-11-20            A. Saidi  17.0        185         67
#
#        team  contract_start  contract_end position  ... total_goalkeeping  \
# 0       MTL          2018.0        2023.0       GK  ...               315
# 1       MTL          2020.0        2023.0      RCB  ...                45
# 2       MTL          2022.0        2023.0       CB  ...                49
# 3       MTL          2021.0        2023.0      LCB  ...                50
# 4       MTL          2020.0        2022.0       RM  ...                50
# ...     ...             ...           ...      ...  ...               ...
# 483224   SD          2024.0        2027.0      RES  ...                52
# 483225   SD             NaN           NaN      NaN  ...                42
# 483226   SD             NaN           NaN      NaN  ...                49
# 483227   SD          2025.0        2027.0      RES  ...                44
# 483228   SD          2025.0        2028.0      RES  ...                57
#
#         gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0              66           63          54              66           66
# 1               6            7          10              11           11
# 2               8            6           6              15           14
# 3               8           11          12               7           12
# 4              11            6          11              11           11
# ...           ...          ...         ...             ...          ...
# 483224         14            7          11               8           12
# 483225         13            8           7               9            5
# 483226         14           10           6              10            9
# 483227         11            6           6              11           10
# 483228          8           14          11               9           15
#
#        marking  tactical_awareness  positioning  tackling
# 0          NaN                 NaN          NaN       NaN
# 1          NaN                 NaN          NaN       NaN
# 2          NaN                 NaN          NaN       NaN
# 3          NaN                 NaN          NaN       NaN
# 4          NaN                 NaN          NaN       NaN
# ...        ...                 ...          ...       ...
# 483224     NaN                 NaN          NaN       NaN
# 483225     NaN                 NaN          NaN       NaN
# 483226     NaN                 NaN          NaN       NaN
# 483227     NaN                 NaN          NaN       NaN
# 483228     NaN                 NaN          NaN       NaN
#
# [483229 rows x 61 columns]

# %%
##3 keep player_id, name, height, and foot

df = df[['player_id', 'name', 'height_cm', 'foot']]

# %%
df
# Out:
#         player_id                name  height_cm   foot
# 0          238919         J. Pantemis        188   Left
# 1          255956         J. Waterman        185  Right
# 2          206485          R. Camacho        185  Right
# 3          247648           K. Miller        183   Left
# 4          243574  Z. Brault-Guillard        171  Right
# ...           ...                 ...        ...    ...
# 483224      77495             M. Duah        193  Right
# 483225      75236          L. Bombino        170   Left
# 483226      73870          D. Vazquez        175   Left
# 483227      80612             P. Soma        177  Right
# 483228      77459            A. Saidi        185  Right
#
# [483229 rows x 4 columns]

# %%
### keep only one entry per player_id

df = df.drop_duplicates(subset=['player_id'])

# %%
## save to sql

df.to_sql('players_general', con=engine, if_exists='append', index=False)
# Out:
# 3834
