# %%
import pandas as pd
from sqlalchemy import create_engine

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df = pd.read_csv('../../data_files/cleaned/matches/players/match_players_stats_ids2.csv')

# %%
df
# Out:
#        match_id        date     player_name  minutes  goals  expected_goals  \
# 0      fa05623c  2025-10-18   D. Mihailovic       90      2            0.31
# 1      fa05623c  2025-10-18  D. Etienne Jr.       70      0            0.07
# 2      fa05623c  2025-10-18    J. Cifuentes       90      0            0.02
# 3      fa05623c  2025-10-18       L. Gavran        0      0            0.00
# 4      fa05623c  2025-10-18       R. Laryea       90      0            0.08
# ...         ...         ...             ...      ...    ...             ...
# 37695  1cfa7fdb  2024-02-21      F. Barajas       24      0            0.00
# 37696  1cfa7fdb  2024-02-21        E. Eneli       90      0            0.00
# 37697  1cfa7fdb  2024-02-21      N. Palacio       66      0            0.02
# 37698  1cfa7fdb  2024-02-21    D. Callender       90      2            0.00
# 37699  1cfa7fdb  2024-02-21      Z. MacMath       90      6            0.00
#
# ...

# %%
## rename goals_saved, goals_against, expected_goals_against and Pass to have gk_ prefix

df = df.rename(columns={
    'goals_saved': 'gk_goals_saved',
    'goals_against': 'gk_goals_against',
    'expected_goals_against': 'gk_expected_goals_against',
    'Pass': 'gk_pass'
})

# %%
## remove date column

df = df.drop(columns=['date'])

# %%
df
# Out:
#        match_id     player_name  minutes  goals  expected_goals  \
# 0      fa05623c   D. Mihailovic       90      2            0.31
# 1      fa05623c  D. Etienne Jr.       70      0            0.07
# 2      fa05623c    J. Cifuentes       90      0            0.02
# 3      fa05623c       L. Gavran        0      0            0.00
# 4      fa05623c       R. Laryea       90      0            0.08
# ...         ...             ...      ...    ...             ...
# 37695  1cfa7fdb      F. Barajas       24      0            0.00
# 37696  1cfa7fdb        E. Eneli       90      0            0.00
# 37697  1cfa7fdb      N. Palacio       66      0            0.02
# 37698  1cfa7fdb    D. Callender       90      2            0.00
# 37699  1cfa7fdb      Z. MacMath       90      6            0.00
#
#        shot_conv_perc  on_target  pass_perc  assists  passes  ...  \
# 0                 3.0        3.0       80.6        1      29  ...
# ...

# %%
bad = df[df["match_id"].astype(str).str.len() > 8][["match_id"]]
bad["len"] = bad["match_id"].astype(str).str.len()
bad.sort_values("len", ascending=False).head(50)
# Out:
#                match_id  len
# 15787  52579500000000.0   16
# 15788  52579500000000.0   16
# 15789  52579500000000.0   16
# 15790  52579500000000.0   16
# 15794  52579500000000.0   16
# 15793  52579500000000.0   16
# 15792  52579500000000.0   16
# 15791  52579500000000.0   16
# 15806  52579500000000.0   16
# 15805  52579500000000.0   16
# 15820  52579500000000.0   16
# 15819  52579500000000.0   16
# 15818  52579500000000.0   16
# 15817  52579500000000.0   16
# 15816  52579500000000.0   16
# 15815  52579500000000.0   16
# 15814  52579500000000.0   16
# 15813  52579500000000.0   16
# 15812  52579500000000.0   16
# 15811  52579500000000.0   16
# 15810  52579500000000.0   16
# 15809  52579500000000.0   16
# 15808  52579500000000.0   16
# 15807  52579500000000.0   16
# 15798  52579500000000.0   16
# 15797  52579500000000.0   16
# 15804  52579500000000.0   16
# 15803  52579500000000.0   16
# 15802  52579500000000.0   16
# 15801  52579500000000.0   16
# 15800  52579500000000.0   16
# ...

# %%
### replace match id '143512000000.0' with "bf454f67" 

df['match_id'] = df['match_id'].replace({'143512000000.0': 'bf454f67'})

## replace match id '52579500000000.0' with "8b5be7da"
df['match_id'] = df['match_id'].replace({'52579500000000.0': '8b5be7da'})

# %%
bad = df[df["match_id"].astype(str).str.len() > 8][["match_id"]]
bad["len"] = bad["match_id"].astype(str).str.len()
bad.sort_values("len", ascending=False).head(50)
# Out:
#          match_id  len
# 18285  5.0756e+66   10
# 18286  5.0756e+66   10
# 18287  5.0756e+66   10
# 18288  5.0756e+66   10
# 18289  5.0756e+66   10
# 18290  5.0756e+66   10
# 18291  5.0756e+66   10
# 18292  5.0756e+66   10
# 18293  5.0756e+66   10
# 18294  5.0756e+66   10
# 18295  5.0756e+66   10
# 18296  5.0756e+66   10
# 18297  5.0756e+66   10
# 18298  5.0756e+66   10
# 18299  5.0756e+66   10
# 18300  5.0756e+66   10
# 18301  5.0756e+66   10
# 18302  5.0756e+66   10
# 18303  5.0756e+66   10
# 18304  5.0756e+66   10
# 18305  5.0756e+66   10
# 18306  5.0756e+66   10
# 18307  5.0756e+66   10
# 18308  5.0756e+66   10
# 18309  5.0756e+66   10
# 18310  5.0756e+66   10
# 18311  5.0756e+66   10
# 18312  5.0756e+66   10
# 18313  5.0756e+66   10
# 18314  5.0756e+66   10
# 18315  5.0756e+66   10
# 18316  5.0756e+66   10
# 18317  5.0756e+66   10
# 18318  5.0756e+66   10

# %%
### look at match fa05623c player 237496

df[(df['match_id'] == 'fa05623c') & (df['player_id'] == 237496)]
# Out:
#    match_id    player_name  minutes  goals  expected_goals  shot_conv_perc  \
# 0  fa05623c  D. Mihailovic       90      2            0.31             3.0
#
#    on_target  pass_perc  assists  passes  ...  gk_goals_against  \
# 0        3.0       80.6        1      29  ...               NaN
#
#    gk_expected_goals_against  gk_pass  gk_throws  gk_long_balls  gk_launches  \
# 0                        NaN      NaN        NaN            NaN          NaN
#
#    GK  corners_conceded  club  player_id
# 0 NaN               NaN   tor   237496.0
#
# [1 rows x 32 columns]

# %%
df.to_sql('match_player_stats', con=engine, if_exists='append', index=False)
# Out:
# 37700
