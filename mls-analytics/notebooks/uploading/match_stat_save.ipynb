# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import glob

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df = pd.read_csv('../../data_files/cleaned/matches/cleaned_mls_matches_master.csv')

# %%
df
# Out:
#             date  home_score  away_score  match_id home_team away_team
# 0     2025-10-18           1           1  6c93df59       ATL        DC
# 1     2025-10-18           2           0  f86ec7a3       CLT       PHI
# 2     2025-10-18           3           0  d3e085cd       CIN       MTL
# 3     2025-10-18           3           1  e411ac49       CLB      RBNY
# 4     2025-10-18           2           5  7cf27f31       NSH       MIA
# ...          ...         ...         ...       ...       ...       ...
# 1457  2023-02-25           4           1  a2b8daa3       PHI       CLB
# 1458  2023-02-25           2           3  e5ef0678       ATX       STL
# 1459  2023-02-25           0           1  fbd05677       DAL       MIN
# 1460  2023-02-25           1           2  e74b26e8       VAN       RSL
# 1461  2023-02-26           4           0  181569f7       SEA       COL
#
# [1462 rows x 6 columns]

# %%
df.to_sql('matches', con=engine, if_exists='append', index=False)
# Out:
# 1462

# %%
df2 = pd.read_csv('../../data_files/cleaned/matches/teams/mls_match_team_stats_with_match_id.csv')
df2
# Out:
#             date  general_aerial_duels_won_home  general_blocked_shots_home  \
# 0     2025-07-25                            6.0                         4.0
# 1     2025-07-25                           14.0                         1.0
# 2     2025-07-25                            8.0                         4.0
# 3     2025-07-25                            8.0                         9.0
# 4     2025-07-25                           10.0                         2.0
# ...          ...                            ...                         ...
# 996   2024-09-18                            8.0                         0.0
# 997   2024-09-18                           11.0                         6.0
# 998   2024-09-18                            5.0                         4.0
# 999   2025-09-24                            3.0                         2.0
# 1000  2025-09-24                           12.0                         8.0
#
#       general_blocked_home  general_clean_sheets_home  \
# 0                      4.0                        0.0
# 1                      1.0                        0.0
# 2                      4.0                        0.0
# 3                      9.0                        0.0
# 4                      2.0                        0.0
# ...                    ...                        ...
# 996                    0.0                        0.0
# 997                    6.0                        0.0
# 998                    4.0                        0.0
# 999                    2.0                        0.0
# 1000                   8.0                        0.0
#
#       general_clearances_home  general_corners_home  \
# 0                         6.0                   9.0
# 1                         3.0                   2.0
# 2                         3.0                   4.0
# 3                         8.0                   3.0
# 4                         5.0                   2.0
# ...                       ...                   ...
# 996                      12.0                   2.0
# 997                       1.0                   5.0
# 998                       2.0                   5.0
# 999                       2.0                   4.0
# 1000                      7.0                   4.0
#
#       general_expected_goals_home  general_fouls_home  \
# 0                             3.0                12.0
# 1                             2.0                16.0
# 2                             1.4                 6.0
# 3                             1.1                10.0
# 4                             1.3                12.0
# ...                           ...                 ...
# 996                           2.0                11.0
# 997                           1.4                11.0
# 998                           1.3                 8.0
# 999                           1.0                22.0
# 1000                          2.7                14.0
#
#       general_goalkeeper_saves_home  ...  shooting_blocked_away  \
# 0                               3.0  ...                    2.0
# 1                               1.0  ...                    3.0
# 2                               3.0  ...                    1.0
# 3                               2.0  ...                    3.0
# 4                               4.0  ...                    3.0
# ...                             ...  ...                    ...
# 996                             3.0  ...                    6.0
# 997                             1.0  ...                    3.0
# 998                             2.0  ...                    1.0
# 999                             4.0  ...                    1.0
# 1000                            6.0  ...                    4.0
#
#       shooting_goals_away  shooting_off_target_away  shooting_on_target_away  \
# 0                     3.0                       2.0                      6.0
# 1                     4.0                       1.0                      5.0
# 2                     1.0                       3.0                      4.0
# 3                     3.0                       2.0                      5.0
# 4                     0.0                       1.0                      4.0
# ...                   ...                       ...                      ...
# 996                   2.0                       4.0                      5.0
# 997                   2.0                       3.0                      3.0
# 998                   2.0                       2.0                      4.0
# 999                   4.0                       3.0                      8.0
# 1000                  1.0                       4.0                      7.0
#
#       xg_shots_on_target_away  xg_shots_away  xg_total_team_xg_away  \
# 0                         6.0           10.0                    2.0
# 1                         5.0            9.0                    1.7
# 2                         4.0            8.0                    0.4
# 3                         5.0           11.0                    1.5
# 4                         4.0            9.0                    0.6
# ...                       ...            ...                    ...
# 996                       5.0           16.0                    2.8
# 997                       3.0           10.0                    1.5
# 998                       4.0            7.0                    1.2
# 999                       8.0           12.0                    2.2
# 1000                      7.0           17.0                    1.6
#
#       home_team  away_team  match_id
# 0           CLB        ORL  43ba7695
# 1           DAL        NYC  85bb856a
# 2          LAFC        POR  588d481f
# 3            NE        MTL  1b458adf
# 4            SD        NSH  5bce4433
# ...         ...        ...       ...
# 996         RSL        DAL  10bad8d9
# 997         SEA         SJ  f47d8d83
# 998         TOR        CLB  faff9e6d
# 999         NYC        MIA  3421a14b
# 1000        VAN        POR  a5cf0ebd
#
# [1001 rows x 120 columns]

# %%
### remove date, home team, away team columns

df2 = df2.drop(columns=['date', 'home_team', 'away_team'])

# %%
df2.dtypes
# Out:
# general_aerial_duels_won_home    float64
# general_blocked_shots_home       float64
# general_blocked_home             float64
# general_clean_sheets_home        float64
# general_clearances_home          float64
#                                   ...
# shooting_on_target_away          float64
# xg_shots_on_target_away          float64
# xg_shots_away                    float64
# xg_total_team_xg_away            float64
# match_id                          object
# Length: 117, dtype: object

# %%
### remove general_blocked, general_goals, general_off_target and general_on_target columns for both home and away

df2 = df2.drop(columns=['general_blocked_home', 'general_blocked_away',
                      'general_goals_home', 'general_goals_away',
                        'general_off_target_home', 'general_off_target_away',
                        'general_on_target_home', 'general_on_target_away'])

# %%
df2.to_sql('matches_stats', engine, if_exists='append', index=False)
# Out:
# 1001
