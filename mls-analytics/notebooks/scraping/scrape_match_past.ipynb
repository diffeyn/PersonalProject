# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException, WebDriverException
import time
import hashlib

# %%
options = Options()
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--disable-infobars')  
options.add_argument('--disable-extensions')
options.add_argument('--disable-notifications')

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# %%
def dismiss_cookies(driver, timeout=8):
    wait = WebDriverWait(driver, timeout)
    tried = []

    def _visible(el):
        try:
            return el.is_displayed() and el.is_enabled()
        except Exception:
            return False

    # 0) Give the banner a second to mount
    driver.execute_script("window._probe = Date.now();")
    try:
        wait.until(
            EC.presence_of_all_elements_located((By.CSS_SELECTOR, "body")))
    except TimeoutException:
        pass

    # 1) Direct hit: common OneTrust IDs/classes
    candidates = [
        (By.ID, "onetrust-accept-btn-handler"),
        (By.CSS_SELECTOR, "button#onetrust-accept-btn-handler"),
        (By.CSS_SELECTOR,
         "#onetrust-banner-sdk button#onetrust-accept-btn-handler"),
        (By.CSS_SELECTOR, "button#onetrust-reject-all-handler"
         ),  # sometimes only Reject is visible first
        (By.CSS_SELECTOR, "[data-testid='onetrust-accept-btn-handler']"),
        (By.XPATH,
         "//button[contains(@id,'accept') and contains(translate(., 'ACEPT','acept'),'accept')]"
         ),
        (By.XPATH,
         "//button[contains(@aria-label,'Accept') or contains(normalize-space(.),'Accept')]"
         ),
    ]
    for how, what in candidates:
        tried.append(f"{how}={what}")
        try:
            btn = driver.find_element(how, what)
            if _visible(btn):
                btn.click()
                return True
        except NoSuchElementException:
            continue
        except WebDriverException:
            # Try JS click if the element exists but normal click fails
            try:
                driver.execute_script("arguments[0].click();", btn)
                return True
            except Exception:
                continue

    # 2) If not found, check for a banner container (present but hidden/animating)
    try:
        banner = driver.find_element(By.ID, "onetrust-banner-sdk")
        if _visible(banner):
            try:
                btn = banner.find_element(By.CSS_SELECTOR,
                                          "button[id*='accept']")
                driver.execute_script("arguments[0].click();", btn)
                return True
            except Exception:
                pass
    except NoSuchElementException:
        pass

    # 3)Scan iframes and try inside.
    iframes = driver.find_elements(By.TAG_NAME, "iframe")
    for i, frame in enumerate(iframes):
        # quick filter to avoid costly switches
        src = (frame.get_attribute("src") or "").lower()
        name = (frame.get_attribute("name") or "").lower()
        if any(k in src + name
               for k in ("consent", "onetrust", "privacy", "cookie")):
            tried.append(f"iframe[{i}] src={src or name}")
            try:
                driver.switch_to.frame(frame)
                # try common selectors again inside this frame
                for how, what in candidates:
                    try:
                        btn = WebDriverWait(driver, 2).until(
                            EC.presence_of_element_located((how, what)))
                        if _visible(btn):
                            driver.execute_script(
                                "arguments[0].scrollIntoView({block:'center'});",
                                btn)
                            try:
                                btn.click()
                            except Exception:
                                driver.execute_script("arguments[0].click();",
                                                      btn)
                            driver.switch_to.default_content()
                            return True
                    except Exception:
                        continue
                driver.switch_to.default_content()
            except Exception:
                # ensure we’re back
                try:
                    driver.switch_to.default_content()
                except:
                    pass

    # 4) Last resort: call OneTrust API if it exists, or remove the banner to unblock clicks
    try:
        ok = driver.execute_script("""
            if (window.OneTrust && OneTrust.AcceptAll) { OneTrust.AcceptAll(); return true; }
            const b = document.getElementById('onetrust-banner-sdk');
            if (b) { b.remove(); return 'removed'; }
            return false;
        """)
        if ok:
            return True
    except Exception:
        pass

    print("[cookies] Could not find/close cookie banner. Tried:",
          *tried,
          sep="\n - ")
    return False

# %%
url = 'https://www.mlssoccer.com/schedule/scores#competition=MLS-COM-000001&club=all'

driver.get(url)
wait = WebDriverWait(driver, 10)

try:
    dismiss_cookies(driver, timeout=8)
except:
    print("Cookie button not found or already clicked.")

rounds = 1000000
stop_date = "Tuesday Mar 26, 2011"
matches = []

for i in range(rounds):
    previous_button = wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Previous results']")))

    try:
        time.sleep(5)

        matches_table = wait.until(EC.presence_of_element_located((By.XPATH, '//div[@class="mls-c-schedule__matches"]')))
        if not matches_table:
            print("No matches table found on this page.")
            previous_button.click()
            continue

        for date in matches_table.find_elements(By.CSS_SELECTOR, '.sc-GKYbw.bMOKWx'):
            date_element = date.find_element(By.CSS_SELECTOR, '.sc-hLBbgP.gIKMo').text.strip()

            if date_element == stop_date:
                break

            for match in date.find_elements(By.TAG_NAME, 'a'):

                home_abbr_el = match.find_element(
                    By.XPATH,
                    ".//div[contains(@class,'mls-c-club') and contains(@class,'--home')]"
                    "//span[contains(@class,'mls-c-club__abbreviation')]"
                )

                away_abbr_el = match.find_element(
                    By.XPATH,
                    ".//div[contains(@class,'mls-c-club') and contains(@class,'--away')]"
                    "//span[contains(@class,'mls-c-club__abbreviation')]"
                )
                
                home_team = home_abbr_el.get_attribute("textContent").strip()
                away_team = away_abbr_el.get_attribute("textContent").strip()

                home_score = match.find_elements(By.CSS_SELECTOR, '.mls-c-scorebug__score')[0].text.strip()
                away_score = match.find_elements(By.CSS_SELECTOR, '.mls-c-scorebug__score')[1].text.strip()
                
                match_id = home_team + "_" + away_team + "_" + date_element.replace(" ", "_").replace(",", "")
                match_id = match_id.lower()
                match_id = hashlib.md5(match_id.encode()).hexdigest()[:8]

                print(f"Match found: {date_element} - {home_team} vs {away_team} ({home_score}:{away_score}) and match_id: {match_id} ")
                matches.append({
                    "date": date_element,
                    "home_team": home_team,
                    "away_team": away_team,
                    "home_score": home_score,
                    "away_score": away_score,
                    'match_id': match_id
                })


        previous_button.click()

    except Exception as e:
        print(f"Error occurred: {e}")
        previous_button.click()
print(f"Total unique matches collected: {len(matches)}")

driver.quit()
# Out:
# Match found: Saturday Oct 18 - ATL vs DC (1:1) and match_id: 6c93df59
# Match found: Saturday Oct 18 - CLT vs PHI (2:0) and match_id: f86ec7a3
# Match found: Saturday Oct 18 - CIN vs MTL (3:0) and match_id: d3e085cd
# Match found: Saturday Oct 18 - CLB vs RBNY (3:1) and match_id: e411ac49
# Match found: Saturday Oct 18 - NSH vs MIA (2:5) and match_id: 7cf27f31
# Match found: Saturday Oct 18 - NE vs CHI (2:2) and match_id: 9f7537a0
# Match found: Saturday Oct 18 - NYC vs SEA (1:2) and match_id: bf454f67
# Match found: Saturday Oct 18 - TOR vs ORL (4:2) and match_id: 62c27490
# Match found: Saturday Oct 18 - COL vs LAFC (2:2) and match_id: 42089098
# Match found: Saturday Oct 18 - SKC vs HOU (0:0) and match_id: a7bbedf9
# Match found: Saturday Oct 18 - LA vs MIN (2:1) and match_id: 94412db9
# Match found: Saturday Oct 18 - POR vs SD (0:4) and match_id: 348a835c
# Match found: Saturday Oct 18 - SJ vs ATX (2:1) and match_id: f51f706e
# Match found: Saturday Oct 18 - STL vs RSL (2:2) and match_id: f43f8264
# Match found: Saturday Oct 18 - VAN vs DAL (1:2) and match_id: aa508357
# Match found: Wednesday Oct 8 - LAFC vs TOR (2:0) and match_id: 75d24797
# Match found: Saturday Oct 11 - MIA vs ATL (4:0) and match_id: 7f9d56d1
# Match found: Saturday Oct 11 - ORL vs VAN (1:2) and match_id: 56694b42
# Match found: Saturday Oct 11 - SEA vs RSL (1:0) and match_id: b2a7b06b
# Match found: Saturday Oct 11 - LA vs DAL (2:1) and match_id: 95958514
# Match found: Sunday Oct 12 - ATX vs LAFC (1:0) and match_id: 63f77bac
# Match found: Tuesday Sep 30 - MIA vs CHI (3:5) and match_id: e80671eb
# Match found: Saturday Oct 4 - DC vs CLT (0:1) and match_id: cad97015
# Match found: Saturday Oct 4 - MTL vs NSH (1:1) and match_id: 66761b1c
# Match found: Saturday Oct 4 - DAL vs LA (2:1) and match_id: 0b8c1dde
# Match found: Saturday Oct 4 - MIA vs NE (4:1) and match_id: 3ea434e1
# Match found: Saturday Oct 4 - RBNY vs CIN (0:1) and match_id: 81a6084b
# Match found: Saturday Oct 4 - ORL vs CLB (1:1) and match_id: fba520a4
# Match found: Saturday Oct 4 - PHI vs NYC (1:0) and match_id: e6bdd4dd
# Match found: Saturday Oct 4 - ATX vs STL (1:3) and match_id: 15b099a6
# Match found: Saturday Oct 4 - CHI vs TOR (2:2) and match_id: 53c10d0d
# Match found: Saturday Oct 4 - HOU vs SD (2:4) and match_id: 27dad4ca
# Match found: Saturday Oct 4 - MIN vs SKC (3:0) and match_id: 04117b5d
# Match found: Saturday Oct 4 - RSL vs COL (1:0) and match_id: 78a4479d
# Match found: Saturday Oct 4 - SEA vs POR (1:0) and match_id: f19b9564
# Match found: Sunday Oct 5 - VAN vs SJ (4:1) and match_id: 17901eac
# Match found: Sunday Oct 5 - LAFC vs ATL (1:0) and match_id: af21c9c0
# Match found: Wednesday Sep 24 - NYC vs MIA (0:4) and match_id: 3421a14b
# Match found: Wednesday Sep 24 - VAN vs POR (1:1) and match_id: a5cf0ebd
# Match found: Saturday Sep 27 - TOR vs MIA (1:1) and match_id: eff9a979
# Match found: Saturday Sep 27 - CLT vs MTL (1:4) and match_id: a2d1be5b
# Match found: Saturday Sep 27 - DC vs PHI (0:6) and match_id: 9373f084
# Match found: Saturday Sep 27 - NE vs ATL (2:0) and match_id: f8ebb265
# Match found: Saturday Sep 27 - RBNY vs NYC (2:3) and match_id: 2a61612b
# Match found: Saturday Sep 27 - CHI vs CLB (2:0) and match_id: 1d9f5475
# Match found: Saturday Sep 27 - NSH vs HOU (3:1) and match_id: e339012f
# Match found: Saturday Sep 27 - STL vs LAFC (0:3) and match_id: 19d36f84
# Match found: Saturday Sep 27 - COL vs MIN (1:1) and match_id: 7be52f8f
# Match found: Saturday Sep 27 - RSL vs ATX (3:1) and match_id: a5f3e9c2
# Match found: Saturday Sep 27 - LA vs SKC (4:1) and match_id: 34de47a4
# Match found: Saturday Sep 27 - POR vs DAL (2:2) and match_id: eff064f7
# Match found: Saturday Sep 27 - SD vs SJ (0:1) and match_id: 7100c368
# Match found: Saturday Sep 27 - SEA vs VAN (2:2) and match_id: 850eccf1
# Match found: Sunday Sep 28 - CIN vs ORL (1:1) and match_id: 8fd7040a
# Match found: Tuesday Sep 16 - MIA vs SEA (3:1) and match_id: 03473985
# Match found: Wednesday Sep 17 - NYC vs CLB (3:2) and match_id: c93632b9
# Match found: Wednesday Sep 17 - RSL vs LAFC (1:4) and match_id: 51ccdb6d
# Match found: Saturday Sep 20 - NYC vs CLT (2:0) and match_id: 6cee45f6
# Match found: Saturday Sep 20 - PHI vs NE (1:0) and match_id: 3a177e2f
# Match found: Saturday Sep 20 - ATL vs SD (1:1) and match_id: adc57103
# Match found: Saturday Sep 20 - CLB vs TOR (1:1) and match_id: c7c2d1bf
# Match found: Saturday Sep 20 - MIA vs DC (3:2) and match_id: e6bf7d7d
# Match found: Saturday Sep 20 - MTL vs RBNY (0:2) and match_id: 589bcee6
# Match found: Saturday Sep 20 - ORL vs NSH (3:2) and match_id: 7f53ae2c
# Match found: Saturday Sep 20 - DAL vs COL (3:1) and match_id: d3b2724a
# Match found: Saturday Sep 20 - HOU vs POR (1:0) and match_id: b2d01edb
# Match found: Saturday Sep 20 - SKC vs VAN (0:2) and match_id: 65f3e3d9
# Match found: Saturday Sep 20 - MIN vs CHI (0:3) and match_id: 4b4f02aa
# Match found: Saturday Sep 20 - LA vs CIN (2:3) and match_id: ab0a43ce
# Match found: Saturday Sep 20 - SJ vs STL (1:3) and match_id: 50a61e21
# Match found: Sunday Sep 21 - ATX vs SEA (2:1) and match_id: 2c2c2907
# Match found: Sunday Sep 21 - LAFC vs RSL (4:1) and match_id: 74bd3f90
# Match found: Saturday Sep 13 - ATL vs CLB (4:5) and match_id: a112403d
# Match found: Saturday Sep 13 - CLT vs MIA (3:0) and match_id: f6ce9e5e
# Match found: Saturday Sep 13 - CIN vs NSH (2:1) and match_id: 1366c6ef
# Match found: Saturday Sep 13 - DC vs ORL (1:1) and match_id: c21f73f4
# Match found: Saturday Sep 13 - MTL vs STL (0:2) and match_id: 69a0d792
# Match found: Saturday Sep 13 - NE vs TOR (1:1) and match_id: 0e25803e
# Match found: Saturday Sep 13 - CHI vs NYC (1:3) and match_id: d112a2a3
# Match found: Saturday Sep 13 - DAL vs ATX (2:0) and match_id: 6c3e62e2
# Match found: Saturday Sep 13 - SEA vs LA (2:2) and match_id: bb4c7898
# Match found: Saturday Sep 13 - SJ vs LAFC (2:4) and match_id: b2e6bbce
# Match found: Saturday Sep 13 - COL vs HOU (2:1) and match_id: 01dc53e7
# Match found: Saturday Sep 13 - RSL vs SKC (2:1) and match_id: e3595e90
# Match found: Saturday Sep 13 - VAN vs PHI (7:0) and match_id: 99b569d4
# Match found: Saturday Sep 13 - POR vs RBNY (2:1) and match_id: c8bb5e19
# Match found: Saturday Sep 13 - SD vs MIN (1:3) and match_id: 01218310
# Match found: Saturday Sep 6 - HOU vs LA (1:1) and match_id: 6c923a7a
# Match found: Saturday Sep 6 - CHI vs NE (3:2) and match_id: b66207fb
# Match found: Saturday Sep 6 - STL vs DAL (1:1) and match_id: a411611c
# Match found: Sunday Sep 7 - SKC vs ATX (1:2) and match_id: 04448798
# Match found: Saturday Aug 30 - CIN vs PHI (0:1) and match_id: 190fa8a1
# Match found: Saturday Aug 30 - NE vs CLT (1:2) and match_id: f2ad1a74
# Match found: Saturday Aug 30 - NYC vs DC (1:2) and match_id: c3011e62
# Match found: Saturday Aug 30 - RBNY vs CLB (0:0) and match_id: 9adc5eff
# Match found: Saturday Aug 30 - TOR vs MTL (1:1) and match_id: df9665f4
# Match found: Saturday Aug 30 - ATX vs SJ (3:1) and match_id: 2179b56e
# Match found: Saturday Aug 30 - STL vs HOU (2:3) and match_id: cc4d5fe2
# Match found: Saturday Aug 30 - SKC vs COL (4:2) and match_id: 7517a088
# Match found: Saturday Aug 30 - MIN vs POR (1:1) and match_id: 6c70bc3b
# Match found: Saturday Aug 30 - NSH vs ATL (0:1) and match_id: 86b4b88b
# Match found: Sunday Aug 31 - LAFC vs SD (1:2) and match_id: 9ac8a386
# Match found: Saturday Aug 23 - CIN vs NYC (0:1) and match_id: 0656689a
# Match found: Saturday Aug 23 - CLB vs NE (1:2) and match_id: f3844516
# Match found: Saturday Aug 23 - DC vs MIA (1:1) and match_id: d7b97a08
# Match found: Saturday Aug 23 - MTL vs ATX (3:2) and match_id: 492afcec
# Match found: Saturday Aug 23 - PHI vs CHI (4:0) and match_id: 84f99cb6
# Match found: Saturday Aug 23 - DAL vs LAFC (1:1) and match_id: f5f0bf51
# Match found: Saturday Aug 23 - HOU vs SJ (1:2) and match_id: 47191d08
# Match found: Saturday Aug 23 - NSH vs ORL (5:1) and match_id: d260d4be
# Match found: Saturday Aug 23 - RSL vs MIN (1:3) and match_id: 7b764d24
# Match found: Saturday Aug 23 - VAN vs STL (3:2) and match_id: 94275834
# Match found: Saturday Aug 23 - LA vs COL (3:0) and match_id: 400a1bee
# Match found: Saturday Aug 23 - SD vs POR (0:0) and match_id: 7eb0b375
# Match found: Sunday Aug 24 - ATL vs TOR (0:0) and match_id: 512bb3dc
# Match found: Sunday Aug 24 - CLT vs RBNY (1:0) and match_id: cedf6289
# Match found: Sunday Aug 24 - SEA vs SKC (5:2) and match_id: 69a7576d
# Match found: Saturday Aug 16 - CLT vs RSL (1:0) and match_id: ee76ea69
# Match found: Saturday Aug 16 - MIA vs LA (3:1) and match_id: ca21ef07
# Match found: Saturday Aug 16 - MTL vs DC (1:1) and match_id: 36556e3c
# Match found: Saturday Aug 16 - NE vs LAFC (0:2) and match_id: c7521ae6
# Match found: Saturday Aug 16 - RBNY vs PHI (1:0) and match_id: 3cc6643b
# Match found: Saturday Aug 16 - TOR vs CLB (1:1) and match_id: a2ae9152
# Match found: Saturday Aug 16 - ATX vs DAL (1:1) and match_id: 6fcc2973
# Match found: Saturday Aug 16 - MIN vs SEA (1:0) and match_id: 1f638ad0
# Match found: Saturday Aug 16 - COL vs ATL (3:1) and match_id: 946a9639
# Match found: Saturday Aug 16 - CHI vs STL (3:2) and match_id: 16760364
# Match found: Saturday Aug 16 - POR vs CIN (2:3) and match_id: 75b43d64
# Match found: Saturday Aug 16 - ORL vs SKC (3:1) and match_id: 63717c9f
# Match found: Sunday Aug 17 - NYC vs NSH (2:1) and match_id: ce005705
# Match found: Sunday Aug 17 - SJ vs SD (1:2) and match_id: fbc05b71
# Match found: Sunday Aug 17 - VAN vs HOU (1:1) and match_id: 0ea51ede
# Match found: Saturday Aug 9 - MTL vs ATL (1:1) and match_id: 56f0fee5
# Match found: Saturday Aug 9 - NE vs DC (2:0) and match_id: faef8022
# Match found: Saturday Aug 9 - PHI vs TOR (1:1) and match_id: 13a5f64d
# Match found: Saturday Aug 9 - ATX vs HOU (2:2) and match_id: 784889bf
# Match found: Saturday Aug 9 - CHI vs LAFC (2:2) and match_id: 2b925dbd
# Match found: Saturday Aug 9 - DAL vs POR (2:0) and match_id: 81e072a8
# Match found: Saturday Aug 9 - STL vs NSH (3:1) and match_id: eed54f89
# Match found: Saturday Aug 9 - SKC vs SD (0:2) and match_id: 04565e94
# Match found: Saturday Aug 9 - SJ vs VAN (2:1) and match_id: 9d8ac8b7
# Match found: Sunday Aug 10 - CIN vs CLT (0:1) and match_id: 1411d835
# Match found: Sunday Aug 10 - RBNY vs RSL (2:1) and match_id: 1f35d519
# Match found: Sunday Aug 10 - MIN vs COL (1:2) and match_id: 27eb1178
# Match found: Sunday Aug 10 - ORL vs MIA (4:1) and match_id: e942aabb
# Match found: Sunday Aug 10 - LA vs SEA (0:4) and match_id: 4e0c82f0
# Match found: Friday Jul 25 - NE vs MTL (1:3) and match_id: 1b458adf
# Match found: Friday Jul 25 - DAL vs NYC (3:4) and match_id: 85bb856a
# Match found: Friday Jul 25 - CLB vs ORL (1:3) and match_id: 43ba7695
# Match found: Friday Jul 25 - LAFC vs POR (0:1) and match_id: 588d481f
# Match found: Friday Jul 25 - SD vs NSH (1:0) and match_id: 5bce4433
# Match found: Saturday Jul 26 - MIA vs CIN (0:0) and match_id: 9d2ffd64
# Match found: Saturday Jul 26 - ATL vs SEA (2:2) and match_id: d85d1140
# Match found: Saturday Jul 26 - CLT vs TOR (2:0) and match_id: f864e485
# Match found: Saturday Jul 26 - DC vs ATX (2:4) and match_id: 40fd942a
# Match found: Saturday Jul 26 - PHI vs COL (3:1) and match_id: 0b65c6cb
# Match found: Saturday Jul 26 - CHI vs RBNY (1:0) and match_id: 77c2b919
# Match found: Saturday Jul 26 - STL vs MIN (1:2) and match_id: e3685339
# Match found: Saturday Jul 26 - RSL vs SJ (2:1) and match_id: 0fc63d92
# Match found: Saturday Jul 26 - VAN vs SKC (3:0) and match_id: cb39b50e
# Match found: Wednesday Jul 16 - ATL vs CHI (2:2) and match_id: b5d68c92
# Match found: Wednesday Jul 16 - CLT vs DC (2:1) and match_id: d1820be1
# Match found: Wednesday Jul 16 - CIN vs MIA (3:0) and match_id: 402cc108
# Match found: Wednesday Jul 16 - RBNY vs NE (5:3) and match_id: 865ede79
# Match found: Wednesday Jul 16 - PHI vs MTL (2:1) and match_id: f40bcaba
# Match found: Wednesday Jul 16 - ORL vs NYC (1:2) and match_id: c0d2cf10
# Match found: Wednesday Jul 16 - HOU vs VAN (0:3) and match_id: 99f01c88
# Match found: Wednesday Jul 16 - MIN vs LAFC (0:1) and match_id: 5458c7a0
# Match found: Wednesday Jul 16 - NSH vs CLB (3:0) and match_id: 3079c6ae
# Match found: Wednesday Jul 16 - SEA vs COL (3:3) and match_id: d5e3fcc4
# Match found: Wednesday Jul 16 - LA vs ATX (1:2) and match_id: 416aa11f
# Match found: Wednesday Jul 16 - POR vs RSL (0:1) and match_id: eb8fee96
# Match found: Wednesday Jul 16 - SD vs TOR (0:1) and match_id: 39b69332
# Match found: Wednesday Jul 16 - SJ vs DAL (2:2) and match_id: d33633db
# Match found: Saturday Jul 19 - ATL vs CLT (2:3) and match_id: fc0c2e52
# Match found: Saturday Jul 19 - MTL vs CHI (0:2) and match_id: f3ec60a0
# Match found: Saturday Jul 19 - NE vs ORL (1:2) and match_id: 4dc9a67c
# Match found: Saturday Jul 19 - RBNY vs MIA (1:5) and match_id: af133f72
# Match found: Saturday Jul 19 - CLB vs DC (2:1) and match_id: 93c1f8e7
# Match found: Saturday Jul 19 - DAL vs STL (3:0) and match_id: 8b1558fa
# Match found: Saturday Jul 19 - HOU vs PHI (1:1) and match_id: af949560
# Match found: Saturday Jul 19 - SKC vs NYC (1:1) and match_id: dcdfc9bf
# Match found: Saturday Jul 19 - SEA vs SJ (3:2) and match_id: d2d1977a
# Match found: Saturday Jul 19 - NSH vs TOR (1:0) and match_id: 0694865a
# Match found: Saturday Jul 19 - RSL vs CIN (0:1) and match_id: 6429907a
# Match found: Saturday Jul 19 - LAFC vs LA (3:3) and match_id: 46ebbbe6
# Match found: Saturday Jul 19 - POR vs MIN (1:1) and match_id: c0e16606
# Match found: Saturday Jul 19 - SD vs VAN (1:1) and match_id: fee95203
# Match found: Wednesday Jul 9 - NE vs MIA (1:2) and match_id: 45297261
# Match found: Wednesday Jul 9 - LAFC vs COL (3:0) and match_id: 35901315
# Match found: Saturday Jul 12 - ORL vs MTL (1:1) and match_id: 8d08b325
# Match found: Saturday Jul 12 - PHI vs RBNY (2:0) and match_id: 6d6f0e50
# Match found: Saturday Jul 12 - TOR vs ATL (1:1) and match_id: 6a4128c5
# Match found: Saturday Jul 12 - MIA vs NSH (2:1) and match_id: 368ab239
# Match found: Saturday Jul 12 - ATX vs NE (0:0) and match_id: 7cd702f2
# Match found: Saturday Jul 12 - CHI vs SD (1:2) and match_id: bc358aa8
# Match found: Saturday Jul 12 - SKC vs SEA (2:3) and match_id: 7d729503
# Match found: Saturday Jul 12 - MIN vs SJ (4:1) and match_id: ab65a569
# Match found: Saturday Jul 12 - CIN vs CLB (2:4) and match_id: 0d16cc41
# Match found: Saturday Jul 12 - CLT vs NYC (2:0) and match_id: bbb67f0b
# Match found: Saturday Jul 12 - COL vs VAN (3:0) and match_id: bf357b2d
# Match found: Saturday Jul 12 - RSL vs HOU (1:0) and match_id: e2eb6056
# Match found: Saturday Jul 12 - LA vs DC (2:1) and match_id: b0db1d29
# Match found: Saturday Jul 12 - LAFC vs DAL (2:0) and match_id: 9f088d22
# Match found: Sunday Jul 13 - STL vs POR (2:1) and match_id: f37e7e58
# Match found: Thursday Jul 3 - NYC vs TOR (3:1) and match_id: 36300c60
# Match found: Friday Jul 4 - DAL vs MIN (1:2) and match_id: a3ec5c83
# Match found: Friday Jul 4 - COL vs SKC (1:2) and match_id: 5943776e
# Match found: Friday Jul 4 - LA vs VAN (3:0) and match_id: 252c3a95
# Match found: Saturday Jul 5 - CLT vs ORL (2:2) and match_id: 0cfad28a
# Match found: Saturday Jul 5 - CIN vs CHI (2:1) and match_id: 8230e4d6
# Match found: Saturday Jul 5 - DC vs ATL (0:0) and match_id: 3850e2e3
# Match found: Saturday Jul 5 - MTL vs MIA (1:4) and match_id: 9eeecad8
# Match found: Saturday Jul 5 - NSH vs PHI (1:0) and match_id: 5c793dd3
# Match found: Saturday Jul 5 - RSL vs STL (3:2) and match_id: 2adda438
# Match found: Saturday Jul 5 - POR vs NE (2:1) and match_id: 76865e6e
# Match found: Saturday Jul 5 - SD vs HOU (3:4) and match_id: 52f5353a
# Match found: Saturday Jul 5 - SJ vs RBNY (1:1) and match_id: b232bb42
# Match found: Sunday Jul 6 - SEA vs CLB (1:1) and match_id: 031a0fae
# Match found: Wednesday Jun 25 - CLB vs ATL (3:1) and match_id: d1bcc0c4
# Match found: Wednesday Jun 25 - MTL vs CIN (1:3) and match_id: c914ff98
# Match found: Wednesday Jun 25 - NE vs NSH (2:3) and match_id: 454b773a
# Match found: Wednesday Jun 25 - TOR vs RBNY (1:1) and match_id: a3f20f6b
# Match found: Wednesday Jun 25 - CHI vs PHI (0:1) and match_id: 57d3bbdf
# Match found: Wednesday Jun 25 - DAL vs SJ (2:4) and match_id: d1bab544
# Match found: Wednesday Jun 25 - SKC vs CLT (2:1) and match_id: 201fa950
# Match found: Wednesday Jun 25 - MIN vs HOU (3:1) and match_id: 54768dc9
# Match found: Wednesday Jun 25 - STL vs ORL (2:4) and match_id: 8c7bd392
# Match found: Wednesday Jun 25 - VAN vs SD (3:5) and match_id: dd84369e
# Match found: Wednesday Jun 25 - COL vs LA (2:0) and match_id: 4560f685
# Match found: Saturday Jun 28 - DC vs NSH (0:1) and match_id: b1738124
# Match found: Saturday Jun 28 - MTL vs NYC (1:0) and match_id: 7d90b1bb
# Match found: Saturday Jun 28 - NE vs COL (3:3) and match_id: ad4039b2
# Match found: Saturday Jun 28 - RBNY vs MIN (2:2) and match_id: 58124641
# Match found: Saturday Jun 28 - ORL vs CIN (1:2) and match_id: a000b8a6
# Match found: Saturday Jun 28 - TOR vs POR (3:0) and match_id: 9a41654a
# Match found: Saturday Jun 28 - CHI vs CLT (3:2) and match_id: 5ee0a8b8
# Match found: Saturday Jun 28 - DAL vs SD (2:3) and match_id: e9ff8220
# Match found: Saturday Jun 28 - SKC vs RSL (1:1) and match_id: 61d05a39
# Match found: Saturday Jun 28 - HOU vs STL (1:0) and match_id: 681ee792
# Match found: Saturday Jun 28 - SJ vs LA (1:1) and match_id: 1d7fcfb3
# Match found: Saturday Jun 28 - SEA vs ATX (2:0) and match_id: dea2e577
# Match found: Sunday Jun 29 - CLB vs PHI (1:0) and match_id: 9459af41
# Match found: Sunday Jun 29 - LAFC vs VAN (0:1) and match_id: 48cea0f1
# Match found: Thursday Jun 12 - NYC vs ATL (4:0) and match_id: 97087b78
# Match found: Friday Jun 13 - POR vs SJ (1:1) and match_id: 203cc096
# Match found: Saturday Jun 14 - STL vs LA (3:3) and match_id: 739c0c3f
# Match found: Saturday Jun 14 - CLB vs VAN (2:1) and match_id: 9b0ca92e
# Match found: Saturday Jun 14 - NE vs CIN (0:1) and match_id: 333b1afb
# Match found: Saturday Jun 14 - PHI vs CLT (2:1) and match_id: b4900915
# Match found: Saturday Jun 14 - ATX vs RBNY (2:1) and match_id: 882ed1c0
# Match found: Saturday Jun 14 - CHI vs NSH (0:2) and match_id: b2ff383c
# Match found: Saturday Jun 14 - HOU vs MTL (1:3) and match_id: 57016e47
# Match found: Saturday Jun 14 - SKC vs DAL (2:4) and match_id: b038efd1
# Match found: Saturday Jun 14 - MIN vs SD (2:4) and match_id: 28b96736
# Match found: Saturday Jun 14 - COL vs ORL (0:1) and match_id: fd129b9b
# Match found: Saturday Jun 14 - RSL vs DC (2:0) and match_id: 3be6fca2
# Match found: Saturday Jun 7 - DC vs CHI (1:7) and match_id: e4ff58e0
# Match found: Saturday Jun 7 - COL vs ATX (0:2) and match_id: 60647635
# Match found: Sunday Jun 8 - POR vs STL (2:1) and match_id: 686f0777
# Match found: Sunday Jun 8 - LAFC vs SKC (3:1) and match_id: 930235e0
# Match found: Sunday Jun 8 - VAN vs SEA (3:0) and match_id: e4269f7c
# Match found: Wednesday May 28 - ATL vs ORL (3:2) and match_id: d854d59a
# Match found: Wednesday May 28 - CIN vs DAL (3:3) and match_id: 5b07f0be
# Match found: Wednesday May 28 - DC vs NE (1:1) and match_id: e9029f36
# Match found: Wednesday May 28 - MIA vs MTL (4:2) and match_id: 0a6fbe43
# Match found: Wednesday May 28 - NYC vs HOU (0:3) and match_id: d8e6ce83
# Match found: Wednesday May 28 - RBNY vs CLT (4:2) and match_id: 223201cf
# Match found: Wednesday May 28 - TOR vs PHI (1:2) and match_id: b0e04425
# Match found: Wednesday May 28 - CLB vs NSH (2:2) and match_id: 500e43b7
# Match found: Wednesday May 28 - ATX vs RSL (1:1) and match_id: 68318c1d
# Match found: Wednesday May 28 - SEA vs SD (1:0) and match_id: 85002c68
# Match found: Wednesday May 28 - LA vs SJ (0:1) and match_id: 3dbd33eb
# Match found: Wednesday May 28 - POR vs COL (2:1) and match_id: 871c6c7a
# Match found: Wednesday May 28 - VAN vs MIN (0:0) and match_id: 6ae8f176
# Match found: Saturday May 31 - STL vs SJ (2:1) and match_id: b5b90a0f
# Match found: Saturday May 31 - NSH vs NYC (2:2) and match_id: ff998419
# Match found: Saturday May 31 - RBNY vs ATL (2:0) and match_id: 79bbe694
# Match found: Saturday May 31 - CIN vs DC (1:2) and match_id: 42755f84
# Match found: Saturday May 31 - MIA vs CLB (5:1) and match_id: cd6bc287
# Match found: Saturday May 31 - MTL vs NE (0:3) and match_id: 4791c35c
# Match found: Saturday May 31 - ORL vs CHI (1:3) and match_id: 1a25b568
# Match found: Saturday May 31 - TOR vs CLT (0:2) and match_id: 35d8baf8
# Match found: Saturday May 31 - DAL vs PHI (0:0) and match_id: 61b438ba
# Match found: Saturday May 31 - HOU vs SKC (1:3) and match_id: 81b52d36
# Match found: Saturday May 31 - LA vs RSL (2:0) and match_id: d2b6af38
# Match found: Saturday May 31 - SD vs ATX (2:0) and match_id: cd83356e
# Match found: Sunday Jun 1 - SEA vs MIN (2:3) and match_id: 0085516b
# Match found: Saturday May 24 - SEA vs DAL (1:0) and match_id: 319984e6
# Match found: Saturday May 24 - SD vs LA (2:1) and match_id: 274bd613
# Match found: Saturday May 24 - CLT vs CLB (3:2) and match_id: 92234fad
# Match found: Saturday May 24 - DC vs RBNY (0:2) and match_id: bd89dcb4
# Match found: Saturday May 24 - MTL vs LAFC (2:2) and match_id: 34b3bb9a
# Match found: Saturday May 24 - ORL vs POR (1:0) and match_id: 68a459b3
# Match found: Saturday May 24 - PHI vs MIA (3:3) and match_id: 7f738af2
# Match found: Saturday May 24 - TOR vs NSH (1:2) and match_id: 9aa40385
# Match found: Saturday May 24 - SKC vs NE (3:3) and match_id: 7be88247
# Match found: Saturday May 24 - MIN vs ATX (1:1) and match_id: 6b7bddee
# Match found: Saturday May 24 - COL vs STL (1:0) and match_id: 2b6336eb
# Match found: Saturday May 24 - RSL vs VAN (2:3) and match_id: 270e74ef
# Match found: Saturday May 24 - SJ vs HOU (3:3) and match_id: 434b0af3
# Match found: Sunday May 25 - NYC vs CHI (3:1) and match_id: c54bbafd
# Match found: Sunday May 25 - ATL vs CIN (4:2) and match_id: a4801b68
# Match found: Wednesday May 14 - DC vs NYC (0:0) and match_id: e90f5180
# Match found: Wednesday May 14 - MTL vs CLB (1:1) and match_id: dd84d1ab
# Match found: Wednesday May 14 - ORL vs CLT (3:1) and match_id: 6d10df45
# Match found: Wednesday May 14 - PHI vs LA (3:2) and match_id: f2256a6a
# Match found: Wednesday May 14 - TOR vs CIN (0:1) and match_id: 5fe35360
# Match found: Wednesday May 14 - HOU vs MIN (2:0) and match_id: 5ab07675
# Match found: Wednesday May 14 - NSH vs RBNY (2:1) and match_id: bd902d02
# Match found: Wednesday May 14 - STL vs SKC (2:2) and match_id: f58fb246
# Match found: Wednesday May 14 - ATX vs ATL (1:1) and match_id: c3f08282
# Match found: Wednesday May 14 - RSL vs POR (0:0) and match_id: 9b266ce6
# Match found: Wednesday May 14 - LAFC vs SEA (4:0) and match_id: afa38a61
# Match found: Wednesday May 14 - SD vs COL (2:0) and match_id: 3ed513b2
# Match found: Wednesday May 14 - SJ vs MIA (3:3) and match_id: 54fc3e54
# Match found: Saturday May 17 - MTL vs TOR (1:6) and match_id: b3774ca0
# Match found: Saturday May 17 - NYC vs RBNY (2:0) and match_id: 3f6ce9cb
# Match found: Saturday May 17 - CLB vs CIN (1:1) and match_id: 3d280d85
# Match found: Saturday May 17 - ATL vs PHI (0:1) and match_id: fd8c6948
# Match found: Saturday May 17 - CLT vs CHI (1:4) and match_id: 279e55f3
# Match found: Saturday May 17 - NE vs SJ (0:0) and match_id: 5bd48883
# Match found: Saturday May 17 - ATX vs VAN (0:0) and match_id: a00d9373
# Match found: Saturday May 17 - DAL vs HOU (0:2) and match_id: 43d10bab
# Match found: Saturday May 17 - MIN vs STL (3:0) and match_id: 85639ac9
# Match found: Saturday May 17 - NSH vs DC (0:0) and match_id: 599f052e
# Match found: Saturday May 17 - COL vs RSL (1:0) and match_id: ddd3b473
# Match found: Saturday May 17 - POR vs SEA (1:1) and match_id: 00f855c4
# Match found: Saturday May 17 - SD vs SKC (0:0) and match_id: 040d0bf7
# Match found: Sunday May 18 - MIA vs ORL (0:3) and match_id: c2f80ca0
# Match found: Sunday May 18 - LA vs LAFC (2:2) and match_id: b6b28baa
# Match found: Saturday May 10 - CHI vs ATL (2:1) and match_id: f857e6aa
# Match found: Saturday May 10 - MIN vs MIA (4:1) and match_id: bb74f9d8
# Match found: Saturday May 10 - TOR vs DC (2:0) and match_id: 8e5a0a07
# Match found: Saturday May 10 - CIN vs ATX (2:1) and match_id: df39e0be
# Match found: Saturday May 10 - NYC vs MTL (0:1) and match_id: dcb27472
# Match found: Saturday May 10 - RBNY vs LA (7:0) and match_id: 15ffd95e
# Match found: Saturday May 10 - ORL vs NE (3:3) and match_id: 0f55ef36
# Match found: Saturday May 10 - PHI vs CLB (2:2) and match_id: 73fd3224
# Match found: Saturday May 10 - DAL vs RSL (1:1) and match_id: db91eb27
# Match found: Saturday May 10 - HOU vs SEA (1:3) and match_id: 401a6cef
# Match found: Saturday May 10 - NSH vs CLT (2:1) and match_id: 1ebc71da
# Match found: Saturday May 10 - STL vs SD (1:2) and match_id: bd09800b
# Match found: Saturday May 10 - COL vs SJ (0:2) and match_id: 5ed03674
# Match found: Saturday May 10 - POR vs SKC (1:0) and match_id: d6048ee0
# Match found: Sunday May 11 - VAN vs LAFC (2:2) and match_id: 0b285e11
# Match found: Saturday May 3 - ATL vs NSH (1:1) and match_id: 0e1ad0f9
# Match found: Saturday May 3 - TOR vs NE (0:2) and match_id: b27fa245
# Match found: Saturday May 3 - CLB vs CLT (4:2) and match_id: 4631878b
# Match found: Saturday May 3 - DC vs COL (2:1) and match_id: 361878b0
# Match found: Saturday May 3 - MIA vs RBNY (4:1) and match_id: 5d238900
# Match found: Saturday May 3 - MTL vs PHI (1:2) and match_id: 28f5382c
# Match found: Saturday May 3 - ATX vs MIN (0:3) and match_id: 017efbdf
# Match found: Saturday May 3 - CHI vs ORL (0:0) and match_id: 322f517b
# Match found: Saturday May 3 - SD vs DAL (5:0) and match_id: d2cad69a
# Match found: Saturday May 3 - VAN vs RSL (2:1) and match_id: f25652a2
# Match found: Saturday May 3 - LAFC vs HOU (2:0) and match_id: 5ea0e9dc
# Match found: Saturday May 3 - SJ vs POR (4:1) and match_id: 0ae1ab06
# Match found: Saturday May 3 - SEA vs STL (4:1) and match_id: 5a82400b
# Match found: Sunday May 4 - NYC vs CIN (1:0) and match_id: c38a5c49
# Match found: Sunday May 4 - SKC vs LA (1:0) and match_id: e40f5b8b
# Match found: Saturday Apr 26 - CIN vs SKC (2:1) and match_id: 9230bac6
# Match found: Saturday Apr 26 - TOR vs NYC (0:1) and match_id: ee734a67
# Match found: Saturday Apr 26 - RBNY vs MTL (1:0) and match_id: d12e099a
# Match found: Saturday Apr 26 - PHI vs DC (3:0) and match_id: c98e85a2
# Match found: Saturday Apr 26 - ORL vs ATL (3:0) and match_id: 7181f57a
# Match found: Saturday Apr 26 - CLT vs NE (0:1) and match_id: b698ecfa
# Match found: Saturday Apr 26 - CLB vs SJ (2:1) and match_id: 1ce51dce
# Match found: Saturday Apr 26 - SD vs RSL (1:3) and match_id: 792d8c54
# Match found: Saturday Apr 26 - HOU vs ATX (2:0) and match_id: 95edf446
# Match found: Saturday Apr 26 - NSH vs CHI (7:2) and match_id: 5c2ddf8d
# Match found: Saturday Apr 26 - COL vs SEA (1:1) and match_id: 62454be7
# Match found: Sunday Apr 27 - MIN vs VAN (1:3) and match_id: 9d18afc3
# Match found: Sunday Apr 27 - MIA vs DAL (3:4) and match_id: ad38dbba
# Match found: Sunday Apr 27 - LAFC vs STL (2:2) and match_id: ae4617e9
# Match found: Sunday Apr 27 - LA vs POR (2:4) and match_id: aa511bdc
# Match found: Saturday Apr 19 - ATX vs LA (1:0) and match_id: f27e7e37
# Match found: Saturday Apr 19 - CLB vs MIA (0:1) and match_id: 5828d6cb
# Match found: Saturday Apr 19 - CLT vs SD (3:0) and match_id: 6362fe8e
# Match found: Saturday Apr 19 - MTL vs ORL (0:0) and match_id: c98c525e
# Match found: Saturday Apr 19 - NE vs NYC (2:0) and match_id: 08a51430
# Match found: Saturday Apr 19 - RBNY vs DC (1:2) and match_id: 98ad29d9
# Match found: Saturday Apr 19 - SEA vs NSH (3:0) and match_id: 004e5096
# Match found: Saturday Apr 19 - PHI vs ATL (3:0) and match_id: 42a02f59
# Match found: Saturday Apr 19 - CHI vs CIN (2:3) and match_id: 1c8ce202
# Match found: Saturday Apr 19 - HOU vs COL (2:2) and match_id: 95e82ba3
# Match found: Saturday Apr 19 - STL vs VAN (0:0) and match_id: 5c33c9e1
# Match found: Saturday Apr 19 - MIN vs DAL (0:0) and match_id: 66ab953e
# Match found: Saturday Apr 19 - RSL vs TOR (0:1) and match_id: d9e13b95
# Match found: Saturday Apr 19 - POR vs LAFC (3:3) and match_id: fc0b3bec
# Match found: Saturday Apr 19 - SJ vs SKC (3:5) and match_id: a54f7a29
# Match found: Saturday Apr 12 - TOR vs MIN (0:0) and match_id: 448da278
# Match found: Saturday Apr 12 - ATL vs NE (0:1) and match_id: f2f36963
# Match found: Saturday Apr 12 - ORL vs RBNY (0:0) and match_id: d85ffe05
# Match found: Saturday Apr 12 - DC vs CIN (0:1) and match_id: c3ade9d4
# Match found: Saturday Apr 12 - MTL vs CLT (0:1) and match_id: 4d9ecba8
# Match found: Saturday Apr 12 - NYC vs PHI (1:0) and match_id: 6bcd9a9b
# Match found: Saturday Apr 12 - VAN vs ATX (5:1) and match_id: 7a66d5bd
# Match found: Saturday Apr 12 - DAL vs SEA (0:1) and match_id: 7e34f9af
# Match found: Saturday Apr 12 - NSH vs RSL (2:1) and match_id: a743dd17
# Match found: Saturday Apr 12 - COL vs SD (3:2) and match_id: 18a4afa1
# Match found: Saturday Apr 12 - LA vs HOU (1:1) and match_id: cffeb417
# Match found: Saturday Apr 12 - LAFC vs SJ (2:1) and match_id: d1190bc7
# Match found: Sunday Apr 13 - SKC vs POR (2:4) and match_id: b7040b4b
# Match found: Sunday Apr 13 - CHI vs MIA (0:0) and match_id: 8242223a
# Match found: Sunday Apr 13 - STL vs CLB (1:2) and match_id: 4b4b1d80
# Match found: Saturday Apr 5 - CLT vs NSH (2:1) and match_id: c1502c5e
# Match found: Saturday Apr 5 - RSL vs LA (2:0) and match_id: 58cf4940
# Match found: Saturday Apr 5 - ATL vs DAL (1:1) and match_id: 106691e3
# Match found: Saturday Apr 5 - CIN vs NE (1:0) and match_id: 04a124f7
# Match found: Saturday Apr 5 - CLB vs MTL (2:1) and match_id: 979c8ca5
# Match found: Saturday Apr 5 - RBNY vs CHI (2:1) and match_id: d6f3e03d
# Match found: Saturday Apr 5 - PHI vs ORL (0:0) and match_id: 12327c9e
# Match found: Saturday Apr 5 - ATX vs POR (0:0) and match_id: 3176e4d5
# Match found: Saturday Apr 5 - SKC vs STL (2:0) and match_id: d5786f5d
# Match found: Saturday Apr 5 - HOU vs LAFC (1:0) and match_id: 2272cbaa
# Match found: Saturday Apr 5 - VAN vs COL (2:0) and match_id: 1dca85dc
# Match found: Saturday Apr 5 - SD vs SEA (3:0) and match_id: c6d0e910
# Match found: Sunday Apr 6 - NYC vs MIN (1:2) and match_id: a87232a6
# Match found: Sunday Apr 6 - SJ vs DC (6:1) and match_id: e140290c
# Match found: Sunday Apr 6 - MIA vs TOR (1:1) and match_id: bf4e43e3
# Match found: Saturday Mar 29 - NE vs RBNY (2:1) and match_id: 8bc9ae35
# Match found: Saturday Mar 29 - TOR vs VAN (0:0) and match_id: 4c022bf9
# Match found: Saturday Mar 29 - COL vs CLT (2:0) and match_id: 444ad09f
# Match found: Saturday Mar 29 - ATL vs NYC (4:3) and match_id: 21184b08
# Match found: Saturday Mar 29 - DC vs CLB (1:2) and match_id: c12478bc
# Match found: Saturday Mar 29 - MIA vs PHI (2:1) and match_id: 2f575666
# Match found: Saturday Mar 29 - CHI vs MTL (1:1) and match_id: ea09758d
# Match found: Saturday Mar 29 - DAL vs SKC (2:1) and match_id: eb0d8838
# Match found: Saturday Mar 29 - MIN vs RSL (2:0) and match_id: 5df31675
# Match found: Saturday Mar 29 - NSH vs CIN (1:2) and match_id: 80d493d0
# Match found: Saturday Mar 29 - LA vs ORL (1:2) and match_id: 6519dca4
# Match found: Saturday Mar 29 - SD vs LAFC (3:2) and match_id: 9410ab7c
# Match found: Saturday Mar 29 - SJ vs SEA (1:1) and match_id: b4ca3759
# Match found: Sunday Mar 30 - STL vs ATX (0:1) and match_id: 9cb7944b
# Match found: Sunday Mar 30 - POR vs HOU (3:1) and match_id: 8b5be7da
# Match found: Saturday Mar 22 - CIN vs ATL (2:2) and match_id: d48abef7
# Match found: Saturday Mar 22 - MIN vs LA (2:2) and match_id: 79d3014f
# Match found: Saturday Mar 22 - CLT vs SJ (4:1) and match_id: 512d1dc3
# Match found: Saturday Mar 22 - CLB vs NYC (0:0) and match_id: 8468eebd
# Match found: Saturday Mar 22 - RBNY vs TOR (2:1) and match_id: b17625af
# Match found: Saturday Mar 22 - ORL vs DC (4:1) and match_id: 6e9ab8a3
# Match found: Saturday Mar 22 - PHI vs STL (1:0) and match_id: fe7bfdf4
# Match found: Saturday Mar 22 - SKC vs LAFC (0:2) and match_id: 0e99be96
# Match found: Saturday Mar 22 - NSH vs MTL (3:0) and match_id: 67841816
# Match found: Saturday Mar 22 - COL vs POR (0:3) and match_id: c02d1adb
# Match found: Saturday Mar 22 - RSL vs DAL (0:1) and match_id: 010fb2bd
# Match found: Saturday Mar 22 - SEA vs HOU (0:0) and match_id: cd9a8e95
# Match found: Saturday Mar 22 - VAN vs CHI (1:3) and match_id: a7e3c780
# Match found: Sunday Mar 23 - ATX vs SD (2:1) and match_id: b74942d0
# Match found: Saturday Mar 15 - TOR vs CHI (1:2) and match_id: c048d633
# Match found: Saturday Mar 15 - RBNY vs ORL (2:2) and match_id: 65b5a0be
# Match found: Saturday Mar 15 - LAFC vs ATX (0:1) and match_id: c7a38480
# Match found: Saturday Mar 15 - CLT vs CIN (2:0) and match_id: 4d711aed
# Match found: Saturday Mar 15 - DC vs MTL (0:0) and match_id: 0b4c29cf
# Match found: Saturday Mar 15 - NYC vs NE (2:1) and match_id: e379e535
# Match found: Saturday Mar 15 - SKC vs MIN (3:3) and match_id: 27618305
# Match found: Saturday Mar 15 - DAL vs VAN (0:1) and match_id: b2f1525d
# Match found: Saturday Mar 15 - HOU vs RSL (1:2) and match_id: a7708102
# Match found: Saturday Mar 15 - STL vs SEA (1:0) and match_id: 98fcdbae
# Match found: Saturday Mar 15 - SD vs CLB (1:1) and match_id: bdd298e6
# Match found: Saturday Mar 15 - SJ vs COL (1:2) and match_id: 521cd0ec
# Match found: Sunday Mar 16 - PHI vs NSH (1:3) and match_id: 831b3f2e
# Match found: Sunday Mar 16 - POR vs LA (1:1) and match_id: 9467a083
# Match found: Sunday Mar 16 - ATL vs MIA (1:2) and match_id: 2546ba31
# Match found: Saturday Mar 8 - CLB vs HOU (0:0) and match_id: 61f9413f
# Match found: Saturday Mar 8 - SEA vs LAFC (5:2) and match_id: 9c2872dd
# Match found: Saturday Mar 8 - ATL vs RBNY (0:0) and match_id: 16d7b318
# Match found: Saturday Mar 8 - CIN vs TOR (2:0) and match_id: acfb7fb5
# Match found: Saturday Mar 8 - DC vs SKC (2:1) and match_id: 3b9094e3
# Match found: Saturday Mar 8 - NE vs PHI (0:2) and match_id: 762f4021
# Match found: Saturday Mar 8 - NYC vs ORL (2:1) and match_id: bfcc8e7c
# Match found: Saturday Mar 8 - ATX vs COL (0:1) and match_id: 621b160b
# Match found: Saturday Mar 8 - DAL vs CHI (1:3) and match_id: 377f8f20
# Match found: Saturday Mar 8 - NSH vs POR (2:0) and match_id: afb410e3
# Match found: Saturday Mar 8 - RSL vs SD (1:3) and match_id: 38cf634c
# Match found: Saturday Mar 8 - VAN vs MTL (2:0) and match_id: 639c9327
# Match found: Saturday Mar 8 - SJ vs MIN (0:1) and match_id: a63bd4e9
# Match found: Sunday Mar 9 - MIA vs CLT (1:0) and match_id: 09c32d06
# Match found: Sunday Mar 9 - LA vs STL (0:3) and match_id: bb2efdea
# Match found: Saturday Mar 1 - CLT vs ATL (2:0) and match_id: 4cd673c0
# Match found: Saturday Mar 1 - RSL vs SEA (2:0) and match_id: 158f8021
# Match found: Saturday Mar 1 - NE vs CLB (0:1) and match_id: 3230992f
# Match found: Saturday Mar 1 - RBNY vs NSH (2:0) and match_id: 27e99fdd
# Match found: Saturday Mar 1 - ORL vs TOR (4:2) and match_id: 4fd6cd27
# Match found: Saturday Mar 1 - PHI vs CIN (4:1) and match_id: ddaa5d8d
# Match found: Saturday Mar 1 - CHI vs DC (2:2) and match_id: db27cb1f
# Match found: Saturday Mar 1 - SKC vs SJ (1:2) and match_id: 215c9f7d
# Match found: Saturday Mar 1 - MIN vs MTL (1:0) and match_id: 3ff94029
# Match found: Saturday Mar 1 - COL vs DAL (3:3) and match_id: ebac5605
# Match found: Saturday Mar 1 - SD vs STL (0:0) and match_id: 187442b1
# Match found: Saturday Mar 1 - LAFC vs NYC (1:0) and match_id: 0e6f6a2b
# Match found: Saturday Mar 1 - POR vs ATX (1:0) and match_id: e53cc2bd
# Match found: Sunday Mar 2 - VAN vs LA (2:1) and match_id: b1bdaebf
# Match found: Sunday Mar 2 - HOU vs MIA (1:4) and match_id: 9e504b76
# Match found: Saturday Feb 22 - LAFC vs MIN (1:0) and match_id: 88188cc8
# Match found: Saturday Feb 22 - MIA vs NYC (2:2) and match_id: 4a6fb3cd
# Match found: Saturday Feb 22 - ATL vs MTL (3:2) and match_id: 0d94a019
# Match found: Saturday Feb 22 - CIN vs RBNY (1:0) and match_id: 3fe26f31
# Match found: Saturday Feb 22 - CLB vs CHI (4:2) and match_id: 03120f02
# Match found: Saturday Feb 22 - DC vs TOR (2:2) and match_id: cbcc85e5
# Match found: Saturday Feb 22 - ORL vs PHI (2:4) and match_id: 1f54f1d9
# Match found: Saturday Feb 22 - ATX vs SKC (1:0) and match_id: fa58216d
# Match found: Saturday Feb 22 - HOU vs DAL (1:2) and match_id: 93bac955
# Match found: Saturday Feb 22 - NSH vs NE (0:0) and match_id: bad5c490
# Match found: Saturday Feb 22 - STL vs COL (0:0) and match_id: 85959f8d
# Match found: Saturday Feb 22 - SJ vs RSL (4:0) and match_id: 5e54b73b
# Match found: Saturday Feb 22 - SEA vs CLT (2:2) and match_id: 88131b8b
# Match found: Sunday Feb 23 - POR vs VAN (1:4) and match_id: 4079b50b
# Match found: Sunday Feb 23 - LA vs SD (0:2) and match_id: 732d482c
# Match found: Saturday Oct 19, 2024 - MTL vs NYC (2:0) and match_id: b2df4b66
# Match found: Saturday Oct 19, 2024 - CHI vs NSH (0:3) and match_id: 73d4b60b
# Match found: Saturday Oct 19, 2024 - DC vs CLT (0:3) and match_id: 772c44fb
# Match found: Saturday Oct 19, 2024 - MIA vs NE (6:2) and match_id: f7019627
# Match found: Saturday Oct 19, 2024 - RBNY vs CLB (2:3) and match_id: ee6703f8
# Match found: Saturday Oct 19, 2024 - ORL vs ATL (1:2) and match_id: 1b68b2f5
# Match found: Saturday Oct 19, 2024 - PHI vs CIN (1:2) and match_id: f8257834
# Match found: Saturday Oct 19, 2024 - ATX vs COL (3:2) and match_id: 418e04e2
# Match found: Saturday Oct 19, 2024 - DAL vs SKC (2:1) and match_id: 9002943e
# Match found: Saturday Oct 19, 2024 - HOU vs LA (2:1) and match_id: 0591a1ac
# Match found: Saturday Oct 19, 2024 - LAFC vs SJ (3:1) and match_id: a8e461ba
# Match found: Saturday Oct 19, 2024 - MIN vs STL (4:1) and match_id: 898b029d
# Match found: Saturday Oct 19, 2024 - RSL vs VAN (2:1) and match_id: 2fa05dd8
# Match found: Saturday Oct 19, 2024 - SEA vs POR (1:1) and match_id: fdafff5b
# Match found: Saturday Oct 12, 2024 - CLB vs NE (4:0) and match_id: e45c6196
# Match found: Sunday Oct 13, 2024 - VAN vs LAFC (1:2) and match_id: 85abea9f
# Match found: Wednesday Oct 2, 2024 - ATL vs MTL (1:2) and match_id: 3d623458
# Match found: Wednesday Oct 2, 2024 - CLT vs CHI (4:3) and match_id: 0e522b06
# Match found: Wednesday Oct 2, 2024 - NYC vs CIN (3:2) and match_id: 1707311b
# Match found: Wednesday Oct 2, 2024 - ORL vs PHI (2:1) and match_id: 2ba59007
# Match found: Wednesday Oct 2, 2024 - TOR vs RBNY (1:4) and match_id: 1c8e3f16
# Match found: Wednesday Oct 2, 2024 - CLB vs MIA (2:3) and match_id: e3fd3e9a
# Match found: Wednesday Oct 2, 2024 - HOU vs NE (2:1) and match_id: bacd802f
# Match found: Wednesday Oct 2, 2024 - NSH vs DC (3:4) and match_id: 26772e42
# Match found: Wednesday Oct 2, 2024 - COL vs LA (1:3) and match_id: c43713d9
# Match found: Wednesday Oct 2, 2024 - RSL vs MIN (0:0) and match_id: 9b53b3bd
# Match found: Wednesday Oct 2, 2024 - LAFC vs STL (1:0) and match_id: 67579095
# Match found: Wednesday Oct 2, 2024 - POR vs ATX (0:1) and match_id: b174fb0c
# Match found: Wednesday Oct 2, 2024 - SJ vs DAL (3:2) and match_id: ac105c6f
# Match found: Wednesday Oct 2, 2024 - VAN vs SEA (0:3) and match_id: 1e1b07ed
# Match found: Saturday Oct 5, 2024 - TOR vs MIA (0:1) and match_id: 6281e4b2
# Match found: Saturday Oct 5, 2024 - VAN vs MIN (0:1) and match_id: bb010175
# Match found: Saturday Oct 5, 2024 - ATL vs RBNY (2:1) and match_id: fed30350
# Match found: Saturday Oct 5, 2024 - CLT vs MTL (2:0) and match_id: 669201ed
# Match found: Saturday Oct 5, 2024 - CLB vs PHI (3:2) and match_id: e539a942
# Match found: Saturday Oct 5, 2024 - CIN vs ORL (1:3) and match_id: 173137d7
# Match found: Saturday Oct 5, 2024 - NE vs DC (1:2) and match_id: eb2ae36b
# Match found: Saturday Oct 5, 2024 - SKC vs LAFC (0:3) and match_id: 1ab644c3
# Match found: Saturday Oct 5, 2024 - STL vs HOU (3:0) and match_id: cb9e1a95
# Match found: Saturday Oct 5, 2024 - COL vs SEA (0:1) and match_id: f9f4f661
# Match found: Saturday Oct 5, 2024 - LA vs ATX (2:1) and match_id: eaaeafb9
# Match found: Saturday Oct 5, 2024 - SJ vs RSL (0:1) and match_id: 41547c10
# Match found: Sunday Oct 6, 2024 - NYC vs NSH (3:1) and match_id: 7f99acfb
# Match found: Sunday Oct 6, 2024 - POR vs DAL (0:0) and match_id: 5ab503f2
# Match found: Saturday Sep 28, 2024 - MTL vs SJ (3:0) and match_id: cac19ec0
# Match found: Saturday Sep 28, 2024 - DC vs CLB (2:2) and match_id: 7519b344
# Match found: Saturday Sep 28, 2024 - CIN vs LAFC (1:2) and match_id: 6b65bfda
# Match found: Saturday Sep 28, 2024 - MIA vs CLT (1:1) and match_id: 69f777f1
# Match found: Saturday Sep 28, 2024 - NE vs NSH (1:0) and match_id: dac9d054
# Match found: Saturday Sep 28, 2024 - RBNY vs NYC (1:5) and match_id: 19542c57
# Match found: Saturday Sep 28, 2024 - PHI vs ATL (1:1) and match_id: 716156ca
# Match found: Saturday Sep 28, 2024 - ATX vs RSL (2:2) and match_id: 2edd36fe
# Match found: Saturday Sep 28, 2024 - CHI vs TOR (1:1) and match_id: 50d763f7
# Match found: Saturday Sep 28, 2024 - DAL vs ORL (1:3) and match_id: 555f8692
# Match found: Saturday Sep 28, 2024 - MIN vs COL (3:0) and match_id: 6fa82b2f
# Match found: Saturday Sep 28, 2024 - STL vs SKC (3:1) and match_id: 100cf9c3
# Match found: Saturday Sep 28, 2024 - VAN vs POR (1:1) and match_id: d921cbe4
# Match found: Saturday Sep 28, 2024 - SEA vs HOU (1:0) and match_id: 4600e8b8
# Match found: Wednesday Sep 18, 2024 - ATL vs MIA (2:2) and match_id: 45758733
# Match found: Wednesday Sep 18, 2024 - NE vs MTL (2:2) and match_id: 6cca50b3
# Match found: Wednesday Sep 18, 2024 - NYC vs PHI (1:5) and match_id: 22f2dacc
# Match found: Wednesday Sep 18, 2024 - TOR vs CLB (0:2) and match_id: faff9e6d
# Match found: Wednesday Sep 18, 2024 - ORL vs CLT (2:0) and match_id: bfaef47b
# Match found: Wednesday Sep 18, 2024 - HOU vs VAN (1:1) and match_id: 57ead66f
# Match found: Wednesday Sep 18, 2024 - MIN vs CIN (1:2) and match_id: 79faf71c
# Match found: Wednesday Sep 18, 2024 - NSH vs CHI (1:0) and match_id: 98216295
# Match found: Wednesday Sep 18, 2024 - SKC vs COL (4:1) and match_id: af6c07fa
# Match found: Wednesday Sep 18, 2024 - RSL vs DAL (3:2) and match_id: 10bad8d9
# Match found: Wednesday Sep 18, 2024 - LAFC vs ATX (1:1) and match_id: 7a090328
# Match found: Wednesday Sep 18, 2024 - POR vs LA (4:2) and match_id: ae3bfe19
# Match found: Wednesday Sep 18, 2024 - SEA vs SJ (2:2) and match_id: f47d8d83
# Match found: Saturday Sep 21, 2024 - NYC vs MIA (1:1) and match_id: 57fc2ac5
# Match found: Saturday Sep 21, 2024 - CLT vs NE (4:0) and match_id: e7c2172b
# Match found: Saturday Sep 21, 2024 - MTL vs CHI (2:0) and match_id: 540593f9
# Match found: Saturday Sep 21, 2024 - CLB vs ORL (4:3) and match_id: b6774ea8
# Match found: Saturday Sep 21, 2024 - RBNY vs ATL (2:2) and match_id: e4cef7d5
# Match found: Saturday Sep 21, 2024 - ATX vs HOU (0:1) and match_id: 966d82fc
# Match found: Saturday Sep 21, 2024 - DAL vs LAFC (3:1) and match_id: 6437faab
# Match found: Saturday Sep 21, 2024 - NSH vs CIN (2:2) and match_id: fa04fa1d
# Match found: Saturday Sep 21, 2024 - SKC vs MIN (0:2) and match_id: fe7f44ec
# Match found: Saturday Sep 21, 2024 - COL vs TOR (2:0) and match_id: 9e691867
# Match found: Saturday Sep 21, 2024 - RSL vs POR (3:3) and match_id: 266b6de5
# Match found: Saturday Sep 21, 2024 - LA vs VAN (4:2) and match_id: e59779a3
# Match found: Saturday Sep 21, 2024 - SJ vs STL (1:2) and match_id: b273cee4
# Match found: Sunday Sep 22, 2024 - PHI vs DC (4:0) and match_id: e0a95926
# Match found: Saturday Sep 14, 2024 - ATL vs NSH (0:2) and match_id: a05c0555
# Match found: Saturday Sep 14, 2024 - MTL vs CLT (2:1) and match_id: 3fede36a
# Match found: Saturday Sep 14, 2024 - DC vs NYC (1:1) and match_id: 1acb11ba
# Match found: Saturday Sep 14, 2024 - CIN vs CLB (0:0) and match_id: f833d467
# Match found: Saturday Sep 14, 2024 - MIA vs PHI (3:1) and match_id: be7d0ae9
# Match found: Saturday Sep 14, 2024 - ORL vs NE (3:0) and match_id: acc0be2a
# Match found: Saturday Sep 14, 2024 - TOR vs ATX (2:1) and match_id: c7a6d98c
# Match found: Saturday Sep 14, 2024 - CHI vs RBNY (2:1) and match_id: 07829d94
# Match found: Saturday Sep 14, 2024 - HOU vs RSL (4:1) and match_id: 0efe9f16
# Match found: Saturday Sep 14, 2024 - STL vs MIN (1:3) and match_id: df7ea9b6
# Match found: Saturday Sep 14, 2024 - COL vs POR (2:1) and match_id: de9dfc18
# Match found: Saturday Sep 14, 2024 - VAN vs SJ (2:0) and match_id: 8016ba14
# Match found: Saturday Sep 14, 2024 - LA vs LAFC (4:2) and match_id: dbd635ef
# Match found: Sunday Sep 15, 2024 - SEA vs SKC (2:0) and match_id: 7ada4c86
# Match found: Saturday Sep 7, 2024 - CLB vs SEA (0:4) and match_id: 4170663f
# Match found: Saturday Sep 7, 2024 - NE vs STL (2:2) and match_id: ee52667d
# Match found: Saturday Sep 7, 2024 - RBNY vs SKC (1:1) and match_id: 1617df82
# Match found: Saturday Sep 7, 2024 - HOU vs LAFC (0:0) and match_id: e245690e
# Match found: Saturday Sep 7, 2024 - CHI vs DC (1:2) and match_id: aca9fcf8
# Match found: Saturday Sep 7, 2024 - VAN vs DAL (0:0) and match_id: f60ca65a
# Match found: Wednesday Aug 28, 2024 - PHI vs CLB (0:1) and match_id: eb158657
# Match found: Saturday Aug 31, 2024 - CLT vs ATL (0:1) and match_id: 860826c3
# Match found: Saturday Aug 31, 2024 - CLB vs NYC (4:2) and match_id: fa2c210a
# Match found: Saturday Aug 31, 2024 - CIN vs MTL (4:1) and match_id: 2a0ebfa7
# Match found: Saturday Aug 31, 2024 - RBNY vs PHI (0:2) and match_id: a12d0702
# Match found: Saturday Aug 31, 2024 - ORL vs NSH (3:0) and match_id: d9567477
# Match found: Saturday Aug 31, 2024 - TOR vs DC (1:3) and match_id: cc047fc2
# Match found: Saturday Aug 31, 2024 - ATX vs VAN (0:1) and match_id: cab76387
# Match found: Saturday Aug 31, 2024 - CHI vs MIA (1:4) and match_id: 9fd173db
# Match found: Saturday Aug 31, 2024 - DAL vs COL (2:3) and match_id: 27afc345
# Match found: Saturday Aug 31, 2024 - RSL vs NE (2:0) and match_id: a882a6c0
# Match found: Saturday Aug 31, 2024 - LAFC vs HOU (0:2) and match_id: 4238900d
# Match found: Saturday Aug 31, 2024 - POR vs SEA (1:0) and match_id: 603da344
# Match found: Saturday Aug 31, 2024 - SJ vs MIN (1:2) and match_id: 6b57452d
# Match found: Sunday Sep 1, 2024 - STL vs LA (2:1) and match_id: 5b1f66a1
# Match found: Saturday Aug 24, 2024 - MIN vs SEA (2:3) and match_id: fdb753f5
# Match found: Saturday Aug 24, 2024 - MTL vs NE (0:5) and match_id: d7410be8
# Match found: Saturday Aug 24, 2024 - CLT vs RBNY (1:1) and match_id: 72dee69c
# Match found: Saturday Aug 24, 2024 - DC vs DAL (3:4) and match_id: d4ca6006
# Match found: Saturday Aug 24, 2024 - MIA vs CIN (2:0) and match_id: 490a9938
# Match found: Saturday Aug 24, 2024 - NYC vs CHI (2:2) and match_id: d47bb5e5
# Match found: Saturday Aug 24, 2024 - HOU vs TOR (0:1) and match_id: 2a41800f
# Match found: Saturday Aug 24, 2024 - NSH vs ATX (0:2) and match_id: 4612753b
# Match found: Saturday Aug 24, 2024 - SKC vs ORL (3:0) and match_id: a2de240a
# Match found: Saturday Aug 24, 2024 - RSL vs SJ (0:2) and match_id: 5e0f0ff6
# Match found: Saturday Aug 24, 2024 - LA vs ATL (2:0) and match_id: 0b18a94d
# Match found: Saturday Aug 24, 2024 - POR vs STL (4:4) and match_id: f5991b87
# Match found: Wednesday Jul 17, 2024 - ATL vs NYC (2:2) and match_id: 39cd4292
# Match found: Wednesday Jul 17, 2024 - CLB vs CLT (1:1) and match_id: b76cc7ea
# Match found: Wednesday Jul 17, 2024 - CIN vs CHI (0:1) and match_id: 68843fbe
# Match found: Wednesday Jul 17, 2024 - MIA vs TOR (3:1) and match_id: 103eec60
# Match found: Wednesday Jul 17, 2024 - RBNY vs MTL (2:2) and match_id: 3e7cd497
# Match found: Wednesday Jul 17, 2024 - PHI vs NE (5:1) and match_id: f5e2531a
# Match found: Wednesday Jul 17, 2024 - DAL vs ATX (3:1) and match_id: 0969bbf9
# Match found: Wednesday Jul 17, 2024 - MIN vs DC (2:3) and match_id: 1b72cbcc
# Match found: Wednesday Jul 17, 2024 - NSH vs ORL (0:3) and match_id: b45f8605
# Match found: Wednesday Jul 17, 2024 - LA vs COL (3:2) and match_id: cf3e3abe
# Match found: Wednesday Jul 17, 2024 - SJ vs HOU (0:1) and match_id: b270aec4
# Match found: Wednesday Jul 17, 2024 - SEA vs STL (2:0) and match_id: 4896eda6
# Match found: Wednesday Jul 17, 2024 - VAN vs SKC (2:1) and match_id: 465bcb31
# Match found: Wednesday Jul 17, 2024 - LAFC vs RSL (1:1) and match_id: b68e9936
# Match found: Saturday Jul 20, 2024 - ATL vs CLB (2:1) and match_id: d4421fb4
# Match found: Saturday Jul 20, 2024 - MTL vs TOR (0:1) and match_id: e6de1e98
# ...
# Match found: Saturday Apr 7, 2007 - COL vs DC (2:1) and match_id: 8042917f
# Match found: Saturday Apr 7, 2007 - RSL vs DAL (2:2) and match_id: 5139c162
# Match found: Saturday Apr 7, 2007 - CLB vs RBNY (0:0) and match_id: 8195cba0
# Match found: Saturday Apr 7, 2007 - CHI vs NE (1:0) and match_id: 386f8805
# Match found: Saturday Apr 7, 2007 - CHV vs TOR (2:0) and match_id: 78d245da
# Match found: Sunday Apr 8, 2007 - HOU vs LA (0:0) and match_id: c3634ab2
# Match found: Saturday Oct 14, 2006 - NE vs CLB (1:0) and match_id: 367ccd25
# Match found: Saturday Oct 14, 2006 - RBNY vs KCW (3:2) and match_id: 19c33326
# Match found: Saturday Oct 14, 2006 - HOU vs COL (3:3) and match_id: 428a76e9
# Match found: Saturday Oct 14, 2006 - LA vs DAL (5:2) and match_id: 1bfd86e8
# Match found: Sunday Oct 15, 2006 - DC vs CHI (2:3) and match_id: cea39981
# Match found: Sunday Oct 15, 2006 - CHV vs RSL (1:1) and match_id: c1010807
# Match found: Saturday Oct 7, 2006 - DC vs NE (1:2) and match_id: 271d2afc
# Match found: Saturday Oct 7, 2006 - KCW vs CHV (2:1) and match_id: b63e7932
# Match found: Saturday Oct 7, 2006 - CHI vs CLB (1:4) and match_id: 78b3afbe
# Match found: Saturday Oct 7, 2006 - DAL vs LA (2:1) and match_id: b500d98a
# Match found: Saturday Oct 7, 2006 - RSL vs HOU (1:1) and match_id: c9aafc65
# Match found: Saturday Oct 7, 2006 - COL vs RBNY (1:1) and match_id: b5efdfa9
# Match found: Saturday Sep 30, 2006 - RBNY vs CHI (1:0) and match_id: b776026f
# Match found: Saturday Sep 30, 2006 - NE vs COL (3:1) and match_id: 02dc9cd9
# Match found: Saturday Sep 30, 2006 - CLB vs DAL (3:1) and match_id: a4de5fc7
# Match found: Saturday Sep 30, 2006 - HOU vs DC (1:0) and match_id: 9d881eec
# Match found: Saturday Sep 30, 2006 - KCW vs RSL (3:3) and match_id: 6010f396
# Match found: Saturday Sep 30, 2006 - LA vs CHV (3:0) and match_id: 659f1f6d
# Match found: Wednesday Sep 20, 2006 - RBNY vs NE (0:2) and match_id: 5a0afcac
# Match found: Saturday Sep 23, 2006 - CLB vs HOU (1:1) and match_id: 006cc75b
# Match found: Saturday Sep 23, 2006 - NE vs KCW (1:1) and match_id: 6208d1de
# Match found: Saturday Sep 23, 2006 - DC vs RBNY (4:3) and match_id: f6687f2f
# Match found: Saturday Sep 23, 2006 - CHI vs LA (2:1) and match_id: 636b6f99
# Match found: Saturday Sep 23, 2006 - DAL vs RSL (2:1) and match_id: 264edfa8
# Match found: Saturday Sep 23, 2006 - CHV vs COL (1:0) and match_id: f80bd11d
# Match found: Wednesday Sep 13, 2006 - NE vs DC (1:1) and match_id: c6f8ee5a
# Match found: Wednesday Sep 13, 2006 - DAL vs CHV (0:1) and match_id: 41469502
# Match found: Wednesday Sep 13, 2006 - COL vs CHI (1:0) and match_id: db5cda65
# Match found: Saturday Sep 16, 2006 - RBNY vs CLB (1:0) and match_id: 218ff747
# Match found: Saturday Sep 16, 2006 - RSL vs DAL (3:2) and match_id: 03f92e56
# Match found: Saturday Sep 16, 2006 - LA vs COL (0:0) and match_id: a10ec297
# Match found: Sunday Sep 17, 2006 - CHI vs DC (1:0) and match_id: 6ceb085a
# Match found: Sunday Sep 17, 2006 - HOU vs CHV (0:0) and match_id: bceda622
# Match found: Saturday Sep 9, 2006 - CLB vs CHI (1:2) and match_id: 064a6c25
# Match found: Saturday Sep 9, 2006 - NE vs RBNY (1:0) and match_id: f12eba8e
# Match found: Saturday Sep 9, 2006 - DC vs RSL (1:1) and match_id: 73c6cdd0
# Match found: Saturday Sep 9, 2006 - KCW vs COL (4:1) and match_id: 0b34bdde
# Match found: Saturday Sep 9, 2006 - CHV vs DAL (1:1) and match_id: 48cd2df3
# Match found: Sunday Sep 10, 2006 - LA vs HOU (1:2) and match_id: b8bd7707
# Match found: Wednesday Aug 30, 2006 - KCW vs RBNY (2:2) and match_id: 03999efd
# Match found: Wednesday Aug 30, 2006 - CHI vs HOU (2:2) and match_id: e5595a52
# Match found: Wednesday Aug 30, 2006 - RSL vs LA (1:0) and match_id: 0b428aab
# Match found: Wednesday Aug 30, 2006 - COL vs DAL (0:2) and match_id: 9aa1530b
# Match found: Saturday Sep 2, 2006 - CLB vs NE (3:0) and match_id: 354b491e
# Match found: Saturday Sep 2, 2006 - DAL vs HOU (1:0) and match_id: 358eab31
# Match found: Saturday Sep 2, 2006 - RSL vs COL (0:1) and match_id: afea1911
# Match found: Saturday Sep 2, 2006 - LA vs KCW (2:1) and match_id: a7b44b3a
# Match found: Sunday Sep 3, 2006 - CHV vs DC (1:2) and match_id: be50849c
# Match found: Sunday Sep 3, 2006 - CHI vs RBNY (2:1) and match_id: 76f9e537
# Match found: Saturday Aug 26, 2006 - DC vs LA (2:5) and match_id: 5addb652
# Match found: Saturday Aug 26, 2006 - RBNY vs RSL (6:0) and match_id: 4575f1a2
# Match found: Saturday Aug 26, 2006 - CHI vs COL (1:0) and match_id: 8151604b
# Match found: Saturday Aug 26, 2006 - CHV vs HOU (3:2) and match_id: f8523c1e
# Match found: Sunday Aug 27, 2006 - NE vs CLB (1:0) and match_id: b0548179
# Match found: Sunday Aug 27, 2006 - KCW vs DAL (1:0) and match_id: 9e9d8406
# Match found: Wednesday Aug 16, 2006 - RBNY vs DC (0:0) and match_id: 8dd58add
# Match found: Wednesday Aug 16, 2006 - CLB vs RSL (1:2) and match_id: 058a78e8
# Match found: Wednesday Aug 16, 2006 - CHI vs KCW (3:0) and match_id: b8a89d9a
# Match found: Saturday Aug 19, 2006 - DC vs COL (1:1) and match_id: 6a43b5ff
# Match found: Saturday Aug 19, 2006 - CLB vs RBNY (1:0) and match_id: fab633e1
# Match found: Saturday Aug 19, 2006 - RSL vs HOU (3:1) and match_id: f6ff3af9
# Match found: Saturday Aug 19, 2006 - CHV vs KCW (1:1) and match_id: 50a0b12a
# Match found: Sunday Aug 20, 2006 - NE vs CHI (0:1) and match_id: 11ecc001
# Match found: Sunday Aug 20, 2006 - LA vs DAL (2:0) and match_id: 3535102d
# Match found: Wednesday Aug 9, 2006 - HOU vs LA (0:1) and match_id: 6f6ae6d4
# Match found: Wednesday Aug 9, 2006 - NE vs KCW (0:0) and match_id: 08d4c483
# Match found: Wednesday Aug 9, 2006 - COL vs RSL (1:4) and match_id: c71c65ab
# Match found: Saturday Aug 12, 2006 - CHI vs CHV (1:2) and match_id: 5cadf9e2
# Match found: Saturday Aug 12, 2006 - KCW vs CLB (4:0) and match_id: 12058ed4
# Match found: Saturday Aug 12, 2006 - HOU vs DAL (1:0) and match_id: 233dc173
# Match found: Saturday Aug 12, 2006 - COL vs LA (1:0) and match_id: b266f92c
# Match found: Sunday Aug 6, 2006 - CHV vs NE (1:1) and match_id: 946a6d65
# Match found: Wednesday Jul 26, 2006 - RSL vs CHV (3:3) and match_id: fec05d1c
# Match found: Wednesday Jul 26, 2006 - COL vs HOU (1:0) and match_id: c7f8e1c0
# Match found: Saturday Jul 29, 2006 - DAL vs COL (4:1) and match_id: d3b586e1
# Match found: Saturday Jul 29, 2006 - CHI vs CLB (0:0) and match_id: 1873bc11
# Match found: Saturday Jul 29, 2006 - HOU vs RBNY (1:1) and match_id: c05d01fd
# Match found: Saturday Jul 29, 2006 - KCW vs NE (1:1) and match_id: 4531daa9
# Match found: Saturday Jul 29, 2006 - RSL vs DC (2:1) and match_id: 0f4a7d49
# Match found: Wednesday Jul 19, 2006 - CLB vs RBNY (0:2) and match_id: e1d9b436
# Match found: Thursday Jul 20, 2006 - COL vs CHV (3:3) and match_id: 088ffaa5
# Match found: Saturday Jul 22, 2006 - CLB vs LA (1:1) and match_id: e018a6c0
# Match found: Saturday Jul 22, 2006 - RBNY vs KCW (1:0) and match_id: a00016bc
# Match found: Saturday Jul 22, 2006 - CHI vs DC (1:1) and match_id: f4923870
# Match found: Saturday Jul 22, 2006 - HOU vs NE (1:1) and match_id: c4cbf779
# Match found: Saturday Jul 22, 2006 - RSL vs DAL (0:1) and match_id: 6c7a22cd
# Match found: Friday Jul 14, 2006 - RBNY vs COL (1:0) and match_id: 61b2e6c2
# Match found: Friday Jul 14, 2006 - NE vs RSL (1:3) and match_id: eb8d93eb
# Match found: Saturday Jul 15, 2006 - CHI vs DAL (2:3) and match_id: 4dcc50f3
# Match found: Saturday Jul 15, 2006 - DC vs CLB (3:2) and match_id: 2c23acd6
# Match found: Saturday Jul 15, 2006 - KCW vs HOU (2:3) and match_id: 0eff2318
# Match found: Saturday Jul 15, 2006 - CHV vs LA (0:0) and match_id: 987f4d68
# Match found: Tuesday Jul 4, 2006 - DAL vs DC (0:1) and match_id: dc14c56a
# Match found: Tuesday Jul 4, 2006 - CHI vs KCW (1:0) and match_id: 061baf74
# Match found: Tuesday Jul 4, 2006 - HOU vs CLB (1:1) and match_id: ccee0171
# Match found: Tuesday Jul 4, 2006 - COL vs NE (3:2) and match_id: e9f869e5
# Match found: Tuesday Jul 4, 2006 - RSL vs CHV (0:0) and match_id: 6540c8a0
# Match found: Tuesday Jul 4, 2006 - LA vs RBNY (1:0) and match_id: 3480b398
# Match found: Saturday Jul 8, 2006 - HOU vs CHV (3:1) and match_id: 3f81f2f0
# Match found: Saturday Jul 8, 2006 - CLB vs DC (0:1) and match_id: 74aecfc7
# Match found: Saturday Jul 8, 2006 - DAL vs RBNY (2:1) and match_id: a18cc200
# Match found: Saturday Jul 8, 2006 - CHI vs NE (1:2) and match_id: 983961eb
# Match found: Saturday Jul 8, 2006 - COL vs KCW (1:0) and match_id: 23e4de23
# Match found: Saturday Jul 8, 2006 - LA vs RSL (2:0) and match_id: 03cc376f
# Match found: Wednesday Jun 28, 2006 - RBNY vs CLB (0:0) and match_id: c1f963c2
# Match found: Wednesday Jun 28, 2006 - NE vs DAL (1:0) and match_id: ff5c7f54
# Match found: Wednesday Jun 28, 2006 - KCW vs DC (2:3) and match_id: 4e262b97
# Match found: Wednesday Jun 28, 2006 - CHI vs RSL (2:1) and match_id: af97e29e
# Match found: Wednesday Jun 28, 2006 - CHV vs HOU (1:1) and match_id: f5739b68
# Match found: Saturday Jul 1, 2006 - NE vs RBNY (3:2) and match_id: 3ce50708
# Match found: Saturday Jul 1, 2006 - KCW vs LA (0:2) and match_id: 5c513fb6
# Match found: Saturday Jul 1, 2006 - CHV vs DAL (3:0) and match_id: 6f998afb
# Match found: Wednesday Jun 21, 2006 - DC vs CHI (1:0) and match_id: 4822fb9a
# Match found: Wednesday Jun 21, 2006 - CLB vs NE (1:1) and match_id: 18bb8b26
# Match found: Wednesday Jun 21, 2006 - COL vs CHV (1:1) and match_id: 42946cef
# Match found: Saturday Jun 24, 2006 - CLB vs CHV (1:1) and match_id: ae0e6c5d
# Match found: Saturday Jun 24, 2006 - DC vs KCW (1:0) and match_id: 04716b92
# Match found: Saturday Jun 24, 2006 - DAL vs COL (1:0) and match_id: fa889850
# Match found: Saturday Jun 24, 2006 - RSL vs NE (0:0) and match_id: 0426331f
# Match found: Saturday Jun 24, 2006 - LA vs HOU (0:0) and match_id: 33c9a061
# Match found: Sunday Jun 25, 2006 - CHI vs RBNY (2:0) and match_id: fc554cc1
# Match found: Saturday Jun 17, 2006 - NE vs DC (1:1) and match_id: 1fd2d385
# Match found: Saturday Jun 17, 2006 - RBNY vs LA (2:1) and match_id: 9c6a789c
# Match found: Saturday Jun 17, 2006 - KCW vs CHI (3:2) and match_id: fcde7ad5
# Match found: Saturday Jun 17, 2006 - HOU vs RSL (2:1) and match_id: 8afa4566
# Match found: Sunday Jun 18, 2006 - CHV vs CLB (2:0) and match_id: 93745d29
# Match found: Thursday Jun 8, 2006 - LA vs CHV (1:2) and match_id: 2b486505
# Match found: Friday Jun 9, 2006 - COL vs RSL (1:0) and match_id: 1af8b91f
# Match found: Saturday Jun 10, 2006 - RBNY vs HOU (1:1) and match_id: abb01769
# Match found: Saturday Jun 10, 2006 - CLB vs KCW (0:1) and match_id: 1cc01e0b
# Match found: Sunday Jun 11, 2006 - DAL vs CHV (2:1) and match_id: 2c86e1d6
# Match found: Sunday Jun 11, 2006 - CHI vs NE (3:3) and match_id: 3df85fb4
# Match found: Sunday Jun 11, 2006 - LA vs DC (1:1) and match_id: ecd1db6d
# Match found: Wednesday May 31, 2006 - DC vs CLB (5:1) and match_id: c2215f08
# Match found: Wednesday May 31, 2006 - COL vs LA (1:0) and match_id: 2de76419
# Match found: Saturday Jun 3, 2006 - DC vs NE (1:0) and match_id: 8e850acc
# Match found: Saturday Jun 3, 2006 - DAL vs CLB (1:2) and match_id: 883a1009
# Match found: Saturday Jun 3, 2006 - HOU vs LA (2:1) and match_id: 399a8bad
# Match found: Saturday Jun 3, 2006 - KCW vs RBNY (1:1) and match_id: 97f92e27
# Match found: Saturday Jun 3, 2006 - RSL vs CHI (3:1) and match_id: 4bb22626
# Match found: Saturday Jun 3, 2006 - CHV vs COL (4:1) and match_id: a2670014
# Match found: Wednesday May 24, 2006 - RBNY vs DAL (1:2) and match_id: 8183c5ff
# Match found: Saturday May 27, 2006 - RSL vs COL (2:2) and match_id: 4f817c64
# Match found: Saturday May 27, 2006 - NE vs HOU (1:1) and match_id: b9158509
# Match found: Saturday May 27, 2006 - KCW vs DC (1:3) and match_id: ece470f4
# Match found: Saturday May 27, 2006 - CHV vs CHI (1:0) and match_id: 619acd07
# Match found: Saturday May 20, 2006 - HOU vs CHI (0:1) and match_id: 561ac255
# Match found: Saturday May 20, 2006 - RBNY vs CHV (5:4) and match_id: c8151902
# Match found: Saturday May 20, 2006 - CLB vs DC (1:1) and match_id: 1709a58f
# Match found: Saturday May 20, 2006 - DAL vs NE (4:0) and match_id: a4ecb14a
# Match found: Saturday May 20, 2006 - RSL vs KCW (2:1) and match_id: d417a9f6
# Match found: Saturday May 20, 2006 - LA vs COL (0:1) and match_id: 306f56af
# Match found: Wednesday May 10, 2006 - DAL vs LA (1:0) and match_id: 4b903b23
# Match found: Saturday May 13, 2006 - DAL vs HOU (1:1) and match_id: 31b97ab9
# Match found: Saturday May 13, 2006 - NE vs CHV (3:1) and match_id: 89c57b4f
# Match found: Saturday May 13, 2006 - RBNY vs CHI (1:1) and match_id: 4cc9dc43
# Match found: Saturday May 13, 2006 - CLB vs COL (1:0) and match_id: 594e7469
# Match found: Saturday May 13, 2006 - DC vs KCW (2:1) and match_id: 41ba800e
# Match found: Saturday May 13, 2006 - LA vs RSL (0:3) and match_id: b107fee9
# Match found: Saturday May 6, 2006 - NE vs LA (4:0) and match_id: a8bb1c5c
# Match found: Saturday May 6, 2006 - KCW vs CHI (1:1) and match_id: 574c3da3
# Match found: Saturday May 6, 2006 - HOU vs DAL (4:3) and match_id: 28c64339
# Match found: Saturday May 6, 2006 - RSL vs CLB (0:1) and match_id: 8c681992
# Match found: Saturday May 6, 2006 - COL vs DC (2:1) and match_id: e548203c
# Match found: Saturday Apr 29, 2006 - RSL vs LA (2:3) and match_id: ea686db9
# Match found: Saturday Apr 29, 2006 - DC vs DAL (1:1) and match_id: 57e35135
# Match found: Saturday Apr 29, 2006 - CLB vs KCW (0:1) and match_id: 405d82f2
# Match found: Saturday Apr 29, 2006 - COL vs HOU (0:1) and match_id: 0bd3639f
# Match found: Saturday Apr 29, 2006 - CHV vs RBNY (0:0) and match_id: aaccab90
# Match found: Sunday Apr 30, 2006 - NE vs CHI (1:2) and match_id: 3719ec38
# Match found: Saturday Apr 22, 2006 - RBNY vs DC (1:4) and match_id: 036ec5a2
# Match found: Saturday Apr 22, 2006 - HOU vs RSL (2:1) and match_id: 4f64268d
# Match found: Saturday Apr 22, 2006 - LA vs CLB (0:1) and match_id: 71a8706c
# Match found: Sunday Apr 23, 2006 - DAL vs KCW (2:1) and match_id: c1f7b475
# Match found: Saturday Apr 15, 2006 - CLB vs CHI (1:1) and match_id: 75a31d0d
# Match found: Saturday Apr 15, 2006 - DC vs HOU (2:0) and match_id: 410e9890
# Match found: Saturday Apr 15, 2006 - KCW vs NE (1:0) and match_id: 7b7acf99
# Match found: Saturday Apr 15, 2006 - COL vs DAL (2:2) and match_id: 53861e6f
# Match found: Saturday Apr 15, 2006 - RSL vs RBNY (1:1) and match_id: 0b51b4da
# Match found: Saturday Apr 15, 2006 - CHV vs LA (1:2) and match_id: ec09d7f2
# Match found: Saturday Apr 8, 2006 - DC vs CHV (2:0) and match_id: fead7811
# Match found: Saturday Apr 8, 2006 - RBNY vs NE (0:0) and match_id: 19c931d1
# Match found: Saturday Apr 8, 2006 - HOU vs KCW (1:2) and match_id: 669148a0
# Match found: Saturday Apr 8, 2006 - DAL vs RSL (2:1) and match_id: 2354099f
# Match found: Saturday Apr 8, 2006 - COL vs CLB (3:1) and match_id: db511e85
# Match found: Saturday Apr 8, 2006 - LA vs CHI (1:1) and match_id: cf9585bb
# Match found: Saturday Apr 1, 2006 - DAL vs CHI (3:2) and match_id: 699b492e
# Match found: Saturday Apr 1, 2006 - KCW vs CLB (3:1) and match_id: df04f188
# Match found: Saturday Apr 1, 2006 - LA vs NE (0:1) and match_id: e2833d8f
# Match found: Sunday Apr 2, 2006 - DC vs RBNY (2:2) and match_id: 93295fc7
# Match found: Sunday Apr 2, 2006 - CHV vs RSL (3:0) and match_id: c0bf35f1
# Match found: Sunday Apr 2, 2006 - HOU vs COL (5:2) and match_id: 2b31fc32
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[4], line 16
#      13 matches = []
#      15 for i in range(rounds):
# ---> 16     previous_button = wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Previous results']")))
#      18     try:
#      19         time.sleep(5)
#
# File c:\Users\diffe\anaconda3\Lib\site-packages\selenium\webdriver\support\wait.py:138, in WebDriverWait.until(self, method, message)
#     136         break
#     137     time.sleep(self._poll)
# --> 138 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:

# %%
matches_df = pd.DataFrame(matches)

# %%
matches_df
# Out:
#                       date home_team away_team home_score away_score  match_id
# 0          Saturday Oct 18       ATL        DC          1          1  6c93df59
# 1          Saturday Oct 18       CLT       PHI          2          0  f86ec7a3
# 2          Saturday Oct 18       CIN       MTL          3          0  d3e085cd
# 3          Saturday Oct 18       CLB      RBNY          3          1  e411ac49
# 4          Saturday Oct 18       NSH       MIA          2          5  7cf27f31
# ...                    ...       ...       ...        ...        ...       ...
# 6663  Saturday Apr 1, 2006       KCW       CLB          3          1  df04f188
# 6664  Saturday Apr 1, 2006        LA        NE          0          1  e2833d8f
# 6665    Sunday Apr 2, 2006        DC      RBNY          2          2  93295fc7
# 6666    Sunday Apr 2, 2006       CHV       RSL          3          0  c0bf35f1
# 6667    Sunday Apr 2, 2006       HOU       COL          5          2  2b31fc32
#
# [6668 rows x 6 columns]

# %%
matches_df.to_csv('matches_past.csv', index=False)

# %%
matches = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/db_save/matches_past.csv')

# %%
matches.head()
# Out:
#              date home_team away_team  home_score  away_score
# 0  Tuesday Sep 30       MIA       CHI           3           5
# 1  Saturday Oct 4        DC       CLT           0           1
# 2  Saturday Oct 4       MTL       NSH           1           1
# 3  Saturday Oct 4       DAL        LA           2           1
# 4  Saturday Oct 4       MIA        NE           4           1

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

## remove 'days' from date column

for day in days:
    matches['date'] = matches['date'].str.replace(f'{day} ', '', regex=False)
    
matches.head()
# Out:
#      date home_team away_team  home_score  away_score
# 0  Sep 30       MIA       CHI           3           5
# 1   Oct 4        DC       CLT           0           1
# 2   Oct 4       MTL       NSH           1           1
# 3   Oct 4       DAL        LA           2           1
# 4   Oct 4       MIA        NE           4           1

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

### convert month abbreviations to numbers

for i, month in enumerate(months, start=1):
    matches['date'] = matches['date'].str.replace(month, str(i).zfill(2), regex=False)
matches.head()
# Out:
#     date home_team away_team  home_score  away_score
# 0  09 30       MIA       CHI           3           5
# 1   10 4        DC       CLT           0           1
# 2   10 4       MTL       NSH           1           1
# 3   10 4       DAL        LA           2           1
# 4   10 4       MIA        NE           4           1

# %%
### add / for date formatting

matches['date'] = matches['date'].str.replace(' ', '/', regex=False)

matches.head()
# Out:
#     date home_team away_team  home_score  away_score
# 0  09/30       MIA       CHI           3           5
# 1   10/4        DC       CLT           0           1
# 2   10/4       MTL       NSH           1           1
# 3   10/4       DAL        LA           2           1
# 4   10/4       MIA        NE           4           1

# %%
### if there is no third part of the date, add the year 2025

matches['date'] = matches['date'].apply(lambda x: x if x.count('/') == 2 else f"{x}/2025")

# %%
matches.head()
# Out:
#          date home_team away_team  home_score  away_score
# 0  09/30/2025       MIA       CHI           3           5
# 1   10/4/2025        DC       CLT           0           1
# 2   10/4/2025       MTL       NSH           1           1
# 3   10/4/2025       DAL        LA           2           1
# 4   10/4/2025       MIA        NE           4           1

# %%
### if ',' present, remove it

matches['date'] = matches['date'].str.replace(',', '', regex=False)

# %%
### convert to datetime

matches['date'] = pd.to_datetime(matches['date'], format='%m/%d/%Y')

# %%
matches.head()
# Out:
#         date home_team away_team  home_score  away_score
# 0 2025-09-30       MIA       CHI           3           5
# 1 2025-10-04        DC       CLT           0           1
# 2 2025-10-04       MTL       NSH           1           1
# 3 2025-10-04       DAL        LA           2           1
# 4 2025-10-04       MIA        NE           4           1

# %%
matches
# Out:
#            date home_team away_team  home_score  away_score
# 0    2025-09-30       MIA       CHI           3           5
# 1    2025-10-04        DC       CLT           0           1
# 2    2025-10-04       MTL       NSH           1           1
# 3    2025-10-04       DAL        LA           2           1
# 4    2025-10-04       MIA        NE           4           1
# ...         ...       ...       ...         ...         ...
# 5823 2010-03-27       DAL       HOU           1           1
# 5824 2010-03-27      RBNY       CHI           1           0
# 5825 2010-03-27       KCW        DC           4           0
# 5826 2010-03-27        SJ       RSL           0           3
# 5827 2010-03-27        LA        NE           1           0
#
# [5828 rows x 5 columns]

# %%
from sqlalchemy import create_engine

db_string = 'mysql+pymysql://root:root@127.0.0.1:2022/MLS'

engine = create_engine(db_string)

# %%
old_df = pd.read_sql("SELECT match_id AS old_hash, date, home_team_abbr, away_team_abbr FROM matches", engine)
new_df = matches.rename(columns={
    'home_team': 'home_team_abbr',
    'away_team': 'away_team_abbr'
})

## add 'new hash' column to new_df
new_df = new_df.assign(new_hash=lambda x: x.index + 1)

# make sure dates are datetime.date
old_df["date"] = pd.to_datetime(old_df["date"]).dt.date
new_df["date"] = pd.to_datetime(new_df["date"]).dt.date

# %%
merged = (
    old_df
    .merge(new_df, on=["date", "home_team_abbr", "away_team_abbr"], how="right")
    [["old_hash", "new_hash", "date", "home_team_abbr", "away_team_abbr", 'home_score', 'away_score']]
)

# %%
merged
# Out:
#       old_hash  new_hash        date home_team_abbr away_team_abbr  \
# 0     b58463fd         1  2025-09-30            MIA            CHI
# 1     523f201f         2  2025-10-04             DC            CLT
# 2     98a71c11         3  2025-10-04            MTL            NSH
# 3     fdc39f90         4  2025-10-04            DAL             LA
# 4     62b997f4         5  2025-10-04            MIA             NE
# ...        ...       ...         ...            ...            ...
# 5823  3fe1cb8e      5824  2010-03-27            DAL            HOU
# 5824  2a6593a9      5825  2010-03-27           RBNY            CHI
# 5825  8cddbc7d      5826  2010-03-27            KCW             DC
# 5826  4c33b0f5      5827  2010-03-27             SJ            RSL
# 5827  57be3ff5      5828  2010-03-27             LA             NE
#
#       home_score  away_score
# 0              3           5
# 1              0           1
# 2              1           1
# 3              2           1
# 4              4           1
# ...          ...         ...
# 5823           1           1
# 5824           1           0
# 5825           4           0
# 5826           0           3
# 5827           1           0
#
# [5828 rows x 7 columns]

# %%
## percentage of nan in 'old_hash' column

nan_percentage = merged['old_hash'].isna().mean() * 100
nan_percentage
# Out:
# 0.0

# %%
## rename old hash to match_id and delete new_hash

merged = merged.rename(columns={'old_hash': 'match_id'}).drop(columns=['new_hash'])

# %%
merged
# Out:
#       match_id        date home_team_abbr away_team_abbr  home_score  \
# 0     b58463fd  2025-09-30            MIA            CHI           3
# 1     523f201f  2025-10-04             DC            CLT           0
# 2     98a71c11  2025-10-04            MTL            NSH           1
# 3     fdc39f90  2025-10-04            DAL             LA           2
# 4     62b997f4  2025-10-04            MIA             NE           4
# ...        ...         ...            ...            ...         ...
# 5823  3fe1cb8e  2010-03-27            DAL            HOU           1
# 5824  2a6593a9  2010-03-27           RBNY            CHI           1
# 5825  8cddbc7d  2010-03-27            KCW             DC           4
# 5826  4c33b0f5  2010-03-27             SJ            RSL           0
# 5827  57be3ff5  2010-03-27             LA             NE           1
#
#       away_score
# 0              5
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 5823           1
# 5824           0
# 5825           0
# 5826           3
# 5827           0
#
# [5828 rows x 6 columns]

# %%
clean = lambda s: s.fillna("").str.lower().str.replace(r"\s+", "", regex=True)

merged["date"] = pd.to_datetime(merged["date"])

merged["slug"] = (
    clean(merged["home_team_abbr"])
    + "vs"
    + clean(merged["away_team_abbr"])
    + "-"
    + merged["date"].dt.strftime("%m-%d-%Y")
)

# %%
import hashlib
def hash_match_ids(df: pd.DataFrame, col="slug", out_col="match_id_hash", length=8):
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found.")
    
    df = df.copy()
    df[out_col] = (
        df[col]
        .astype(str)
        .str.lower()
        .map(lambda x: hashlib.md5(x.encode()).hexdigest()[:length])
    )
    
    
    return df

# %%
merged2 = hash_match_ids(merged, col="slug", out_col="match_id_hash", length=8)

# %%
## remove 'slug' column

merged2 = merged2.drop(columns=['slug'], errors='ignore')

# %%
merged2
# Out:
#       match_id       date home_team_abbr away_team_abbr  home_score  \
# 0     b58463fd 2025-09-30            MIA            CHI           3
# 1     523f201f 2025-10-04             DC            CLT           0
# 2     98a71c11 2025-10-04            MTL            NSH           1
# 3     fdc39f90 2025-10-04            DAL             LA           2
# 4     62b997f4 2025-10-04            MIA             NE           4
# ...        ...        ...            ...            ...         ...
# 5823  3fe1cb8e 2010-03-27            DAL            HOU           1
# 5824  2a6593a9 2010-03-27           RBNY            CHI           1
# 5825  8cddbc7d 2010-03-27            KCW             DC           4
# 5826  4c33b0f5 2010-03-27             SJ            RSL           0
# 5827  57be3ff5 2010-03-27             LA             NE           1
#
#       away_score match_id_hash
# 0              5      b58463fd
# 1              1      523f201f
# 2              1      98a71c11
# 3              1      fdc39f90
# 4              1      62b997f4
# ...          ...           ...
# 5823           1      3fe1cb8e
# 5824           0      2a6593a9
# 5825           0      8cddbc7d
# 5826           3      4c33b0f5
# 5827           0      57be3ff5
#
# [5828 rows x 7 columns]

# %%
### if match_id nan, replace with match_id_hash

merged2['match_id'] = merged2.apply(
    lambda row: row['match_id_hash'] if pd.isna(row['match_id']) else row['match_id'],
    axis=1
)

merged2.drop(columns=['match_id_hash'], errors='ignore', inplace=True)

merged2
# Out:
#       match_id       date home_team_abbr away_team_abbr  home_score  \
# 0     b58463fd 2025-09-30            MIA            CHI           3
# 1     523f201f 2025-10-04             DC            CLT           0
# 2     98a71c11 2025-10-04            MTL            NSH           1
# 3     fdc39f90 2025-10-04            DAL             LA           2
# 4     62b997f4 2025-10-04            MIA             NE           4
# ...        ...        ...            ...            ...         ...
# 5823  3fe1cb8e 2010-03-27            DAL            HOU           1
# 5824  2a6593a9 2010-03-27           RBNY            CHI           1
# 5825  8cddbc7d 2010-03-27            KCW             DC           4
# 5826  4c33b0f5 2010-03-27             SJ            RSL           0
# 5827  57be3ff5 2010-03-27             LA             NE           1
#
#       away_score
# 0              5
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 5823           1
# 5824           0
# 5825           0
# 5826           3
# 5827           0
#
# [5828 rows x 6 columns]

# %%
merged2
# Out:
#       match_id       date home_team_abbr away_team_abbr  home_score  \
# 0     b58463fd 2025-09-30            MIA            CHI           3
# 1     523f201f 2025-10-04             DC            CLT           0
# 2     98a71c11 2025-10-04            MTL            NSH           1
# 3     fdc39f90 2025-10-04            DAL             LA           2
# 4     62b997f4 2025-10-04            MIA             NE           4
# ...        ...        ...            ...            ...         ...
# 5823  3fe1cb8e 2010-03-27            DAL            HOU           1
# 5824  2a6593a9 2010-03-27           RBNY            CHI           1
# 5825  8cddbc7d 2010-03-27            KCW             DC           4
# 5826  4c33b0f5 2010-03-27             SJ            RSL           0
# 5827  57be3ff5 2010-03-27             LA             NE           1
#
#       away_score
# 0              5
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 5823           1
# 5824           0
# 5825           0
# 5826           3
# 5827           0
#
# [5828 rows x 6 columns]

# %%
##check duplicates in merged2

merged2['match_id'].duplicated().sum()

## view duplicates

merged2[merged2['match_id'].duplicated(keep=False)].sort_values('match_id')

# %%
## drop first occurrence of duplicates

merged2 = merged2[~merged2['match_id'].duplicated(keep='first')]

### rename to home_team_score and away_team_score

merged2 = merged2.rename(columns={'home_score': 'home_team_score', 'away_score': 'away_team_score'})

# %%
merged2.to_sql('matches', engine, if_exists='append', index=False)
# Out:
# 5824
