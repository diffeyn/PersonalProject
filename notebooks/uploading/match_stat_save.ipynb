# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import glob

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/matches/teams/mls_match_team_stats_reframed0326.csv')

# %%
df
# Out:
#     match_id  general_aerial_duels_won_home  general_blocked_shots_home  \
# 0   08e147bc                            7.0                         8.0
# 1   12769fea                           12.0                         4.0
# 2   1b022c5c                           14.0                         2.0
# 3   2046cddd                           14.0                         2.0
# 4   245c0550                            5.0                         4.0
# 5   2f937f25                           10.0                         7.0
# 6   314976c2                           13.0                         2.0
# 7   384d63a9                            7.0                         7.0
# 8   3f3f51ea                           26.0                         7.0
# 9   5ba741bf                           10.0                         4.0
# 10  5c78a593                            4.0                         0.0
# 11  639d65f2                           14.0                         2.0
# ...

# %%
### chceck coluns in match_team_stats table and df to compare

match_team_stats = pd.read_sql('SELECT * FROM match_team_stats', con=engine)

match_team_stats.columns
# Out:
# Index(['match_id', 'general_possession_pct_home',
#        'general_possession_pct_away', 'general_shots_home',
#        'general_shots_away', 'general_shots_on_goal_home',
#        'general_shots_on_goal_away', 'general_blocked_shots_home',
#        'general_blocked_shots_away', 'general_total_passes_home',
#        ...
#        'possession_81_85_home', 'possession_81_85_away',
#        'possession_86_90_home', 'possession_86_90_away',
#        'xg_total_team_xg_home', 'xg_total_team_xg_away', 'xg_shots_home',
#        'xg_shots_away', 'xg_shots_on_target_home', 'xg_shots_on_target_away'],
#       dtype='object', length=109)

# %%
### find not matching columns between match_team_stats and df

match_team_stats_cols = set(match_team_stats.columns)
df_cols = set(df.columns)

not_matching_cols = match_team_stats_cols.symmetric_difference(df_cols)

print(sorted(not_matching_cols))
# Out:
# ['general_blocked_away', 'general_blocked_home', 'general_goals_away', 'general_goals_home', 'general_off_target_away', 'general_off_target_home', 'general_on_target_away', 'general_on_target_home', 'general_shots_on_goal_away', 'general_shots_on_goal_home', 'general_shots_on_target_home']

# %%
df = df.drop(columns=['general_goals_home', 'general_goals_away', 'general_shots_on_target_home', 'general_on_target_home', 'general_blocked_home', 'general_shots_on_goal_away', 'general_off_target_home', 'general_shots_on_goal_home', 'general_on_target_away', 'general_off_target_away', 'general_blocked_away'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df = df.drop(columns=['general_goals_home', 'general_goals_away', 'general_shots_on_target_home', 'general_on_target_home', 'general_blocked_home', 'general_shots_on_goal_away', 'general_off_target_home', 'general_shots_on_goal_home', 'general_on_target_away', 'general_off_target_away', 'general_blocked_away'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
# ...

# %%
df.to_sql('match_team_stats', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
# ...

# %%
df2 = pd.read_csv('../../data_files/cleaned/matches/teams/mls_match_team_stats_with_match_id.csv')
df2

# %%
### remove date, home team, away team columns

df2 = df2.drop(columns=['date', 'home_team', 'away_team'])

# %%
df2.dtypes

# %%
### remove general_blocked, general_goals, general_off_target and general_on_target columns for both home and away

df2 = df2.drop(columns=['general_blocked_home', 'general_blocked_away',
                      'general_goals_home', 'general_goals_away',
                        'general_off_target_home', 'general_off_target_away',
                        'general_on_target_home', 'general_on_target_away'])

# %%
df2.to_sql('matches_stats', engine, if_exists='append', index=False)
